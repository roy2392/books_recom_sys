# %% [markdown]
# # <center>DLRM model</center>

# %% [markdown]
# ### Import depencies

# %%
from IPython.display import clear_output

# %%
python -c "import fbgemm_gpu"
# Out:
#   Cell In[32], line 1
#     python -c "import fbgemm_gpu"
#               ^
# SyntaxError: invalid syntax

# %%
# Release GPU
conda install pytorch cuda -c pytorch -c "nvidia/label/cuda-11.7.1"
# !pip install fbgemm-gpu
# Out:
#   Cell In[31], line 2
#     conda install pytorch cuda -c pytorch -c "nvidia/label/cuda-11.7.1"
#           ^
# SyntaxError: invalid syntax

# %%
# !pip install fbgemm-gpu
#!pip install fbgemm-gpu-cpu

# !pip install torch
# !pip install torchrec
#!pip install torchrec-cpu
# !pip install pyre_extensions

#clear_output()
# Out:
# ERROR: Could not find a version that satisfies the requirement fbgemm-gpu (from versions: none)
# ERROR: No matching distribution found for fbgemm-gpu
# Requirement already satisfied: torch in /Users/royzalta/anaconda3/lib/python3.11/site-packages (2.0.1)
# Requirement already satisfied: filelock in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torch) (2.8.4)
# Requirement already satisfied: jinja2 in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from sympy->torch) (1.2.1)
# Collecting torchrec
#   Using cached torchrec-0.4.0-py310-none-any.whl (325 kB)
# Requirement already satisfied: iopath in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (0.1.10)
# Requirement already satisfied: pandas in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (1.5.3)
# Requirement already satisfied: tabulate in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (0.8.10)
# Requirement already satisfied: torchmetrics in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (1.0.1)
# Requirement already satisfied: tqdm in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (4.65.0)
# INFO: pip is looking at multiple versions of torchrec to determine which version is compatible with other requirements. This could take a while.
#   Using cached torchrec-0.3.2-py39-none-any.whl (317 kB)
# Requirement already satisfied: arrow==1.2.3 in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (1.2.3)
# Requirement already satisfied: attrs==22.1.0 in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (22.1.0)
# Collecting certifi==2022.12.7 (from torchrec)
#   Using cached certifi-2022.12.7-py3-none-any.whl (155 kB)
# Collecting charset-normalizer==2.1.1 (from torchrec)
#   Using cached charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting cmake==3.25.0 (from torchrec)
#   Using cached cmake-3.25.0-py2.py3-none-macosx_10_10_universal2.macosx_10_10_x86_64.macosx_11_0_arm64.macosx_11_0_universal2.whl (45.1 MB)
# Collecting Cython==0.29.32 (from torchrec)
#   Using cached Cython-0.29.32-py2.py3-none-any.whl (986 kB)
# Requirement already satisfied: distro==1.8.0 in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (1.8.0)
# Collecting docker==6.0.1 (from torchrec)
#   Using cached docker-6.0.1-py3-none-any.whl (147 kB)
# Requirement already satisfied: docstring-parser==0.8.1 in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (0.8.1)
# Collecting torchrec
#   Using cached torchrec-0.3.1-py310-none-any.whl (333 kB)
# Requirement already satisfied: certifi in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (2023.5.7)
# Requirement already satisfied: charset-normalizer in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (2.0.4)
# Requirement already satisfied: cmake in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (3.27.0)
# Requirement already satisfied: Cython in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (3.0.0)
# Requirement already satisfied: docker in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (6.1.3)
#   Using cached torchrec-0.2.0-py39-none-any.whl (293 kB)
# Requirement already satisfied: filelock in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (3.9.0)
# Requirement already satisfied: fsspec in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (2023.4.0)
# Requirement already satisfied: hypothesis in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (6.82.0)
# Requirement already satisfied: idna in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (3.4)
# Requirement already satisfied: Jinja2 in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (3.1.2)
# Requirement already satisfied: MarkupSafe in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (2.1.1)
# Requirement already satisfied: mypy-extensions in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (0.4.3)
# Requirement already satisfied: ninja in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (1.11.1)
# Requirement already satisfied: numpy in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (1.24.3)
# Requirement already satisfied: packaging in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (23.0)
# Requirement already satisfied: portalocker in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (2.7.0)
# Requirement already satisfied: pyarrow in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (11.0.0)
# Requirement already satisfied: pyDeprecate in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (0.3.2)
# Requirement already satisfied: pyparsing in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (3.0.9)
# Collecting pyre-extensions==0.0.27 (from torchrec)
#   Using cached pyre_extensions-0.0.27-py3-none-any.whl (12 kB)
# Requirement already satisfied: python-dateutil in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (2.8.2)
# Requirement already satisfied: pytz in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (2022.7)
# Requirement already satisfied: PyYAML in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (6.0)
# Requirement already satisfied: requests in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (2.29.0)
# Requirement already satisfied: scikit-build in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (0.17.6)
# Requirement already satisfied: six in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (1.16.0)
# Requirement already satisfied: sortedcontainers in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (2.4.0)
# Requirement already satisfied: torchx-nightly in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (2023.6.1)
# Requirement already satisfied: typing-inspect in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (0.9.0)
# Requirement already satisfied: typing-extensions in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (4.5.0)
# Requirement already satisfied: urllib3 in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (1.26.16)
# Collecting usort (from torchrec)
#   Using cached usort-1.0.7-py3-none-any.whl (23 kB)
# Requirement already satisfied: websocket-client in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (0.58.0)
# Collecting torchrec
#   Downloading torchrec-0.1.0-py39-none-any.whl (80.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.1/80.1 MB 5.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pyre-extensions in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (0.0.30)
# Requirement already satisfied: typing in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchrec) (3.7.4.3)
# Requirement already satisfied: setuptools>=42.0.0 in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from scikit-build->torchrec) (67.8.0)
# Requirement already satisfied: wheel>=0.32.0 in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from scikit-build->torchrec) (0.38.4)
# Requirement already satisfied: torch>=1.8.1 in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchmetrics->torchrec) (2.0.1)
# Requirement already satisfied: lightning-utilities>=0.7.0 in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchmetrics->torchrec) (0.9.0)
# Requirement already satisfied: importlib-metadata in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torchx-nightly->torchrec) (6.0.0)
# Requirement already satisfied: sympy in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torch>=1.8.1->torchmetrics->torchrec) (1.11.1)
# Requirement already satisfied: networkx in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from torch>=1.8.1->torchmetrics->torchrec) (2.8.4)
# Requirement already satisfied: zipp>=0.5 in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from importlib-metadata->torchx-nightly->torchrec) (3.11.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.8.1->torchmetrics->torchrec) (1.2.1)
# Installing collected packages: torchrec
# Successfully installed torchrec-0.1.0
# Requirement already satisfied: pyre_extensions in /Users/royzalta/anaconda3/lib/python3.11/site-packages (0.0.30)
# Requirement already satisfied: typing-inspect in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from pyre_extensions) (0.9.0)
# Requirement already satisfied: typing-extensions in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from pyre_extensions) (4.5.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/royzalta/anaconda3/lib/python3.11/site-packages (from typing-inspect->pyre_extensions) (0.4.3)

# %%
# !pip install --upgrade pip
# !pip install --upgrade setuptools
# Out:
# Requirement already satisfied: pip in /Users/royzalta/anaconda3/lib/python3.11/site-packages (23.1.2)
# Collecting pip
#   Downloading pip-23.2.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 5.8 MB/s eta 0:00:00a 0:00:010m
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.1.2
#     Uninstalling pip-23.1.2:
#       Successfully uninstalled pip-23.1.2
# Successfully installed pip-23.2.1
# Requirement already satisfied: setuptools in /Users/royzalta/anaconda3/lib/python3.11/site-packages (67.8.0)
# Collecting setuptools
#   Obtaining dependency information for setuptools from https://files.pythonhosted.org/packages/c7/42/be1c7bbdd83e1bfb160c94b9cafd8e25efc7400346cf7ccdbdb452c467fa/setuptools-68.0.0-py3-none-any.whl.metadata
#   Downloading setuptools-68.0.0-py3-none-any.whl.metadata (6.4 kB)
# Using cached setuptools-68.0.0-py3-none-any.whl (804 kB)
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.8.0
#     Uninstalling setuptools-67.8.0:
#       Successfully uninstalled setuptools-67.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.41 requires requests_mock, which is not installed.
# spyder 5.4.3 requires pyqt5<5.16, which is not installed.
# spyder 5.4.3 requires pyqtwebengine<5.16, which is not installed.
# conda-repo-cli 1.0.41 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.41 requires nbformat==5.4.0, but you have nbformat 5.7.0 which is incompatible.
# conda-repo-cli 1.0.41 requires requests==2.28.1, but you have requests 2.29.0 which is incompatible.
# python-lsp-black 1.2.1 requires black>=22.3.0, but you have black 0.0 which is incompatible.
# Successfully installed setuptools-68.0.0

# %%
conda install -c conda-forge fbgemm_gpu
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - fbgemm_gpu
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge/osx-arm64
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://repo.anaconda.com/pkgs/main/osx-arm64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-arm64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import random

import torch
from torchrec.datasets.utils import Batch
from torchrec.sparse.jagged_tensor import KeyedJaggedTensor
from sklearn.model_selection import train_test_split
#import custom function from book_funcs file
from book_funcs import category_cleaner, df_cleaner, category_cleaner,category_compliter, zero_droper, precentage_null
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[34], line 6
#       3 import random
#       5 import torch
# ----> 6 from torchrec.datasets.utils import Batch
#       7 from torchrec.sparse.jagged_tensor import KeyedJaggedTensor
#       8 from sklearn.model_selection import train_test_split
#
# File ~/anaconda3/lib/python3.11/site-packages/torchrec/__init__.py:8
#       1 #!/usr/bin/env python3
#       2 # Copyright (c) Meta Platforms, Inc. and affiliates.
#       3 # All rights reserved.
#       4 #
#       5 # This source code is licensed under the BSD-style license found in the
#       6 # LICENSE file in the root directory of this source tree.
# ----> 8 import torchrec.distributed  # noqa
#       9 import torchrec.quant  # noqa
#      10 from torchrec.fx import tracer  # noqa
#
# File ~/anaconda3/lib/python3.11/site-packages/torchrec/distributed/__init__.py:8
#       1 #!/usr/bin/env python3
#       2 # Copyright (c) Meta Platforms, Inc. and affiliates.
#       3 # All rights reserved.
#       4 #
#       5 # This source code is licensed under the BSD-style license found in the
#       6 # LICENSE file in the root directory of this source tree.
# ----> 8 from torchrec.distributed.model_parallel import DistributedModelParallel  # noqa
#       9 from torchrec.distributed.train_pipeline import (  # noqa
#      10     TrainPipeline,
#      11     TrainPipelineBase,
#      12     TrainPipelineSparseDist,
#      13 )
#      14 from torchrec.distributed.types import (  # noqa
#      15     Awaitable,
#      16     NoWait,
#    (...)
#      22     ShardingEnv,
#      23 )
#
# File ~/anaconda3/lib/python3.11/site-packages/torchrec/distributed/model_parallel.py:17
#      15 from torch.nn.modules.module import _IncompatibleKeys
#      16 from torch.nn.parallel import DistributedDataParallel
# ---> 17 from torchrec.distributed.embeddingbag import (
#      18     EmbeddingBagCollectionSharder,
#      19 )
#      20 from torchrec.distributed.planner import (
#      21     EmbeddingShardingPlanner,
#      22     sharder_name,
#      23     Topology,
#      24 )
#      25 from torchrec.distributed.quant_embeddingbag import QuantEmbeddingBagCollectionSharder
#
# File ~/anaconda3/lib/python3.11/site-packages/torchrec/distributed/embeddingbag.py:28
#      26 from torch import nn
#      27 from torch.nn.modules.module import _IncompatibleKeys
# ---> 28 from torchrec.distributed.cw_sharding import CwEmbeddingSharding
#      29 from torchrec.distributed.dp_sharding import DpEmbeddingSharding
#      30 from torchrec.distributed.embedding_sharding import (
#      31     EmbeddingSharding,
#      32     SparseFeaturesListAwaitable,
#      33 )
#
# File ~/anaconda3/lib/python3.11/site-packages/torchrec/distributed/cw_sharding.py:12
#      10 import torch
#      11 import torch.distributed as dist  # noqa
# ---> 12 from fbgemm_gpu.permute_pooled_embedding_modules import PermutePooledEmbeddings
#      13 from torchrec.distributed.embedding_types import (
#      14     ShardedEmbeddingTable,
#      15     EmbeddingComputeKernel,
#      16 )
#      17 from torchrec.distributed.tw_sharding import TwEmbeddingSharding, TwPooledEmbeddingDist
#
# File ~/anaconda3/lib/python3.11/site-packages/fbgemm_gpu/__init__.py:12
#       8 import os
#      10 import torch
# ---> 12 torch.ops.load_library(os.path.join(os.path.dirname(__file__), "fbgemm_gpu_py.so"))
#      14 # __init__.py is only used in OSS
#      15 # Use existence to check if fbgemm_gpu_py.so has already been loaded
#      16 open_source: bool = True
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/_ops.py:643, in _Ops.load_library(self, path)
#     638 path = _utils_internal.resolve_library_path(path)
#     639 with dl_open_guard():
#     640     # Import the shared library into the process, thus running its
#     641     # static (global) initialization code in order to register custom
#     642     # operators with the JIT.
# --> 643     ctypes.CDLL(path)
#     644 self.loaded_libraries.add(path)
#
# File ~/anaconda3/lib/python3.11/ctypes/__init__.py:376, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     373 self._FuncPtr = _FuncPtr
#     375 if handle is None:
# --> 376     self._handle = _dlopen(self._name, mode)
#     377 else:
#     378     self._handle = handle
#
# OSError: dlopen(/Users/royzalta/anaconda3/lib/python3.11/site-packages/fbgemm_gpu/fbgemm_gpu_py.so, 0x0006): tried: '/Users/royzalta/anaconda3/lib/python3.11/site-packages/fbgemm_gpu/fbgemm_gpu_py.so' (not a mach-o file), '/System/Volumes/Preboot/Cryptexes/OS/Users/royzalta/anaconda3/lib/python3.11/site-packages/fbgemm_gpu/fbgemm_gpu_py.so' (no such file), '/Users/royzalta/anaconda3/lib/python3.11/site-packages/fbgemm_gpu/fbgemm_gpu_py.so' (not a mach-o file)

# %%
from batch import *
from model import *

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device: '{device}'")

# %% [markdown]
# ### Import Data

# %%
df = pd.read_csv(r'/Users/royzalta/Downloads/archive/Books Data with Category Language and Summary/Preprocessed_data.csv')

# %%
df['age'] = df['age'].astype(int)
df['year_of_publication'] = df['year_of_publication'].astype(int)

# %% [markdown]
# ### train & test split

# %%
train_df, test_df = train_test_split(
    df, test_size=0.33, random_state=42)

# %% [markdown]
# ### Apply custom transformers

# %%
train_df = category_cleaner(train_df)
train_df = df_cleaner(train_df)
train_df = category_compliter(train_df)
train_df = zero_droper(train_df)
# Out:
# The original data frame shape:	(690887, 19)
# The data frame shape after bookk filtering:	(376474, 19)
# The new data frame shape:	(340545, 19)
# /Users/royzalta/Documents/GitHub/books_recom_sys/book_funcs.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_author9_relevant_two_options['pred_Category'] = df_author9_relevant_two_options['Category'].apply(

# %% [markdown]
# ### Handle null values

# %%
null_train = precentage_null(train_df)
print(null_train)
# Out:
# user_id                0.000000
# location               0.000000
# age                    0.000000
# isbn                   0.000000
# rating                 0.000000
# book_title             0.000000
# book_author            0.000000
# year_of_publication    0.000000
# publisher              0.000000
# img_s                  0.000000
# img_m                  0.000000
# img_l                  0.000000
# Summary                0.000000
# Language               0.000000
# Category               0.000000
# city                   2.258757
# state                  3.170026
# country                5.074356
# dtype: float64
# None

# %%
columns_to_check = ["city", "state", "country"]
train_df = train_df.dropna(subset=columns_to_check, how="any")

# %%
null_test = precentage_null(test_df)
print(null_test)
# Out:
# Unnamed: 0             0.000000
# user_id                0.000000
# location               0.000000
# age                    0.000000
# isbn                   0.000000
# rating                 0.000000
# book_title             0.000000
# book_author            0.000000
# year_of_publication    0.000000
# publisher              0.000000
# img_s                  0.000000
# img_m                  0.000000
# img_l                  0.000000
# Summary                0.000000
# Language               0.000000
# Category               0.000000
# city                   1.361494
# state                  2.204603
# country                3.443848
# dtype: float64
# None

# %%
columns_to_check = ["city", "state", "country"]
test_df = test_df.dropna(subset=columns_to_check, how="any")

# %% [markdown]
# ### Encoding sparse features

# %%
cols_dense = ["age", "year_of_publication"]
cols_sparse = ['location',
               'publisher','Language','Category',
              'city','state','country']

# %%
def encode(col, map_rev):
    encoded_values = []
    for item in col:
        if pd.notna(item):  # Check if the value is not NaN
            encoded_value = map_rev.get(item, item)
            encoded_values.append(encoded_value)
        else:
            # Handle NaN values as needed
            encoded_values.append('NaN')
    return encoded_values

# %%
map_sparse = {}
map_sparse_rev = {}

# %%
for feat in cols_sparse:
    map_sparse[feat] = {i: c for i,c in enumerate(train_df[feat].explode().value_counts().index)}
    map_sparse_rev[feat] = {v:k for k, v in map_sparse[feat].items()}

    train_df[feat+'_enc'] = train_df[feat].apply(lambda x: encode(x, map_sparse_rev[feat]))
    test_df[feat+'_enc'] = test_df[feat].apply(lambda x: encode(x, map_sparse_rev[feat]))

# %%
map_sparse
# Out:
# {'location': {0: 'toronto, ontario, canada',
#   1: 'chicago, illinois, usa',
#   2: 'seattle, washington, usa',
#   3: 'morrow, georgia, usa',
#   4: 'portland, oregon, usa',
#   5: 'calgary, alberta, canada',
#   6: 'san diego, california, usa',
#   7: 'mechanicsville, maryland, usa',
#   8: 'houston, texas, usa',
#   9: 'ottawa, ontario, canada',
#   10: 'new york, new york, usa',
#   11: 'london, england, united kingdom',
#   12: 'san antonio, texas, usa',
#   13: 'austin, texas, usa',
#   14: 'st. louis, missouri, usa',
#   15: 'san francisco, california, usa',
#   16: 'vancouver, british columbia, canada',
#   17: 'edmonton, alberta, canada',
#   18: 'honolulu, hawaii, usa',
#   19: 'ft. stewart, georgia, usa',
#   20: 'sydney, new south wales, australia',
#   21: 'tucson, arizona, usa',
#   22: 'orlando, florida, usa',
#   23: 'san jose, california, usa',
#   24: 'minneapolis, minnesota, usa',
#   25: 'charleston, west virginia, usa',
#   26: 'cincinnati, ohio, usa',
#   27: 'topeka, kansas, usa',
#   28: 'albuquerque, new mexico, usa',
#   29: 'los angeles, california, usa',
#   30: 'sacramento, california, usa',
#   31: 'brooklyn, new york, usa',
#   32: 'louisville, kentucky, usa',
#   33: 'omaha, nebraska, usa',
#   34: 'pittsburgh, pennsylvania, usa',
#   35: 'lisboa, lisboa, portugal',
#   36: 'tulsa, oklahoma, usa',
#   37: 'akron, ohio, usa',
#   38: 'oakland, california, usa',
#   39: 'simi valley, california, usa',
#   40: 'cleveland, ohio, usa',
#   41: 'fredericton, new brunswick, canada',
#   42: 'halifax, nova scotia, canada',
#   43: 'st louis, missouri, usa',
#   44: 'duluth, minnesota, usa',
#   45: 'victoria, british columbia, canada',
#   46: 'atlanta, georgia, usa',
#   47: 'philadelphia, pennsylvania, usa',
#   48: 'las vegas, nevada, usa',
#   49: 'baltimore, maryland, usa',
#   50: 'colorado springs, colorado, usa',
#   51: 'olympia, washington, usa',
#   52: 'long beach, california, usa',
#   53: 'wichita, kansas, usa',
#   54: 'phoenix, arizona, usa',
#   55: 'alexandria, virginia, usa',
#   56: 'fairbanks, alaska, usa',
#   57: 'virginia beach, virginia, usa',
#   58: 'christchurch, canterbury, new zealand',
#   59: 'youngstown, ohio, usa',
#   60: 'dallas, texas, usa',
#   61: 'ft. pierce, florida, usa',
#   62: 'alvin, texas, usa',
#   63: 'milwaukee, wisconsin, usa',
#   64: 'rochester, new york, usa',
#   65: 'sunnyvale, california, usa',
#   66: 'montreal, quebec, canada',
#   67: 'charleston, south carolina, usa',
#   68: 'kitchener, ontario, canada',
#   69: 'winnipeg, manitoba, canada',
#   70: 'asheville, north carolina, usa',
#   71: 'fresno, california, usa',
#   72: 'manchester, new hampshire, usa',
#   73: 'bellingham, washington, usa',
#   74: 'denver, colorado, usa',
#   75: 'ginsheim, hessen, germany',
#   76: 'hamburg, hamburg, germany',
#   77: 'huntington beach, california, usa',
#   78: 'jacksonville, florida, usa',
#   79: 'barcelona, catalunya, spain',
#   80: 'miami, florida, usa',
#   81: 'hyde park, new york, usa',
#   82: 'jasper, missouri, usa',
#   83: 'new orleans, louisiana, usa',
#   84: 'ann arbor, michigan, usa',
#   85: 'raleigh, north carolina, usa',
#   86: 'cary, north carolina, usa',
#   87: 'charlotte, north carolina, usa',
#   88: 'marietta, georgia, usa',
#   89: 'london, ontario, canada',
#   90: 'beaverton, oregon, usa',
#   91: 'nashua, new hampshire, usa',
#   92: 'kansas city, missouri, usa',
#   93: 'bad axe, michigan, usa',
#   94: 'torrance, california, usa',
#   95: 'burlington, ontario, canada',
#   96: 'rapid city, south dakota, usa',
#   97: 'hawthorne, new jersey, usa',
#   98: 'melbourne, victoria, australia',
#   99: 'mesa, arizona, usa',
#   100: 'kelso, washington, usa',
#   101: 'lexington, kentucky, usa',
#   102: 'amadora, lisboa, portugal',
#   103: 'lincoln, nebraska, usa',
#   104: 'tampa, florida, usa',
#   105: 'modesto, california, usa',
#   106: 'birmingham, alabama, usa',
#   107: 'chula vista, california, usa',
#   108: 'little rock, arkansas, usa',
#   109: 'winnemucca, nevada, usa',
#   110: 'pleasanton, california, usa',
#   111: 'santa cruz, california, usa',
#   112: 'evanston, illinois, usa',
#   113: 'la mesa, california, usa',
#   114: 'boston, massachusetts, usa',
#   115: 'el cajon, california, usa',
#   116: 'sherman oaks, california, usa',
#   117: 'howell, new jersey, usa',
#   118: 'vista, california, usa',
#   119: 'roanoke, virginia, usa',
#   120: 'nashville, tennessee, usa',
#   121: 'washington, dc, usa',
#   122: 'knoxville, tennessee, usa',
#   123: 'boise, idaho, usa',
#   124: 'richmond, virginia, usa',
#   125: 'indianapolis, indiana, usa',
#   126: 'cordova, tennessee, usa',
#   127: 'santa rosa, california, usa',
#   128: 'henryville, indiana, usa',
#   129: 'spring, texas, usa',
#   130: 'norfolk, virginia, usa',
#   131: 'kirkland, washington, usa',
#   132: 'tarentum, pennsylvania, usa',
#   133: 'indiana, pennsylvania, usa',
#   134: 'salt lake city, utah, usa',
#   135: 'madrid, madrid, spain',
#   136: 'tallahassee, florida, usa',
#   137: 'santo domingo, distrito nacional, dominican republic',
#   138: 'west sacramento, california, usa',
#   139: 'somerville, massachusetts, usa',
#   140: 'savannah, georgia, usa',
#   141: 'adelaide, south australia, australia',
#   142: 'fort worth, texas, usa',
#   143: 'sioux falls, south dakota, usa',
#   144: 'wiley ford, west virginia, usa',
#   145: 'vancouver, washington, usa',
#   146: 'cumberland, maryland, usa',
#   147: 'lakeland, florida, usa',
#   148: 'carmichael, california, usa',
#   149: 'fpo, ap, usa',
#   150: 'eugene, oregon, usa',
#   151: 'santa ana, california, usa',
#   152: 'plano, texas, usa',
#   153: 'barren springs, virginia, usa',
#   154: 'mountain view, california, usa',
#   155: 'paris, ile de france, france',
#   156: 'tehran, tehran, iran',
#   157: 'durham, north carolina, usa',
#   158: 'mcqueeney, texas, usa',
#   159: 'columbia, south carolina, usa',
#   160: 'springfield, missouri, usa',
#   161: 'amarillo, texas, usa',
#   162: 'arlington, virginia, usa',
#   163: 'anchorage, alaska, usa',
#   164: 'oklahoma city, oklahoma, usa',
#   165: 'livermore, california, usa',
#   166: 'livermore, maine, usa',
#   167: 'tigard, oregon, usa',
#   168: 'temple, texas, usa',
#   169: 'hobe sound, florida, usa',
#   170: 'detroit, michigan, usa',
#   171: 'berkeley, california, usa',
#   172: 'memphis, tennessee, usa',
#   173: 'berlin, berlin, germany',
#   174: 'shanghai, shanghai, china',
#   175: 'madison, wisconsin, usa',
#   176: 'nj, new jersey, usa',
#   177: 'mclean, virginia, usa',
#   178: 'carlsbad, california, usa',
#   179: 'columbia, missouri, usa',
#   180: 'huntsville, alabama, usa',
#   181: 'hayward, california, usa',
#   182: 'westmont, illinois, usa',
#   183: 'byron, minnesota, usa',
#   184: 'corvallis, oregon, usa',
#   185: 'wahiawa, hawaii, usa',
#   186: 'kuching, sarawak, malaysia',
#   187: 'chapel hill, north carolina, usa',
#   188: 'portland, maine, usa',
#   189: 'barcelona, barcelona, spain',
#   190: 'gahanna/columbus, ohio, usa',
#   191: 'prince george, british columbia, canada',
#   192: 'oakland, new jersey, usa',
#   193: 'ashburn, virginia, usa',
#   194: 'las cruces, new mexico, usa',
#   195: 'irving, texas, usa',
#   196: 'clevelad, ohio, usa',
#   197: 'columbus, ohio, usa',
#   198: 'greenville, illinois, usa',
#   199: 'westerville, ohio, usa',
#   200: 'waltham, massachusetts, usa',
#   201: 'duncansville, pennsylvania, usa',
#   202: 'gilbert, arizona, usa',
#   203: 'maryville, tennessee, usa',
#   204: 'morrisville, north carolina, usa',
#   205: 'burbank, california, usa',
#   206: 'wien, wien, austria',
#   207: 'chesapeake, virginia, usa',
#   208: 'olathe, kansas, usa',
#   209: 'delisle, saskatchewan, canada',
#   210: 'baton rouge, louisiana, usa',
#   211: 'citrus heights, california, usa',
#   212: 'wilmington, north carolina, usa',
#   213: 'dayton, ohio, usa',
#   214: 'elk grove, california, usa',
#   215: 'boulder, colorado, usa',
#   216: 'delta, british columbia, canada',
#   217: 'deventer, overijssel, netherlands',
#   218: 'sackville, new brunswick, canada',
#   219: 'são paulo, são paulo, brazil',
#   220: 'snellville, georgia, usa',
#   221: 'hamilton, ontario, canada',
#   222: 'cambridge, massachusetts, usa',
#   223: 'lansing, michigan, usa',
#   224: 'gaithersburg, maryland, usa',
#   225: 'wildwood, new jersey, usa',
#   226: 'fairview, new mexico, usa',
#   227: 'surrey, british columbia, canada',
#   228: 'encino, california, usa',
#   229: 'niles, michigan, usa',
#   230: 'puchong, selangor, malaysia',
#   231: 'antioch, illinois, usa',
#   232: 'grand rapids, michigan, usa',
#   233: 'clemson, south carolina, usa',
#   234: 'lynnwood, washington, usa',
#   235: 'astoria, new york, usa',
#   236: 'brainerd, minnesota, usa',
#   237: 'groton, connecticut, usa',
#   238: 'kuala lumpur, federal territory, malaysia',
#   239: 'muskegon, michigan, usa',
#   240: 'monroe twp., new jersey, usa',
#   241: 'san marcos, california, usa',
#   242: 'plainfield, illinois, usa',
#   243: 'apple valley, minnesota, usa',
#   244: 'saskatoon, saskatchewan, canada',
#   245: 'rockaway, new jersey, usa',
#   246: 'reno, nevada, usa',
#   247: 'burnaby, british columbia, canada',
#   248: 'strafford, missouri, usa',
#   249: 'ypsilanti, michigan, usa',
#   250: 'grapeview, washington, usa',
#   251: 'fairfax, virginia, usa',
#   252: 'north vancouver, british columbia, canada',
#   253: 'morro bay, california, usa',
#   254: 'st. charles, missouri, usa',
#   255: 'bellevue, washington, usa',
#   256: 'shelbyville, tennessee, usa',
#   257: 'waterloo, ontario, canada',
#   258: 'fullerton, california, usa',
#   259: 'summerville, south carolina, usa',
#   260: 'boone county, kentucky, usa',
#   261: 'westport, connecticut, usa',
#   262: 'sherwood park, alberta, canada',
#   263: 'homer city, pennsylvania, usa',
#   264: 'chandler, arizona, usa',
#   265: 'antelope, california, usa',
#   266: 'oslo, oslo, norway',
#   267: 'getxo, vizcaya, spain',
#   268: 'granada hills, california, usa',
#   269: 'mississauga, ontario, canada',
#   270: 'bakersfield, california, usa',
#   271: 'columbia, maryland, usa',
#   272: 'mesquite, texas, usa',
#   273: 'florissant, missouri, usa',
#   274: 'lakewood, colorado, usa',
#   275: 'new berlin, wisconsin, usa',
#   276: 'toledo, ohio, usa',
#   277: 'fulton, missouri, usa',
#   278: 'springfield, illinois, usa',
#   279: 'sandy, utah, usa',
#   280: 'kelseyville, california, usa',
#   281: 'providence, rhode island, usa',
#   282: 'yarmouth, nova scotia, canada',
#   283: 'frankston, victoria, australia',
#   284: 'sandpoint, idaho, usa',
#   285: 'wilmington, delaware, usa',
#   286: 'peoria, illinois, usa',
#   287: 'waterford, michigan, usa',
#   288: 'mars, pennsylvania, usa',
#   289: 'concordia, missouri, usa',
#   290: 'duncanville, alabama, usa',
#   291: 'arlington, texas, usa',
#   292: 'ona, west virginia, usa',
#   293: 'sturgis, michigan, usa',
#   294: 'traverse city, michigan, usa',
#   295: 'silver spring, maryland, usa',
#   296: 'culemborg, gelderland, netherlands',
#   297: 'münchen, bayern, germany',
#   298: 'fredericksburg, virginia, usa',
#   299: 'bridgeton, new jersey, usa',
#   300: 'st. paul, minnesota, usa',
#   301: 'muskego, wisconsin, usa',
#   302: 'college station, texas, usa',
#   303: 'tacoma, washington, usa',
#   304: 'spokane, washington, usa',
#   305: 'moline, illinois, usa',
#   306: 'oceanside, new york, usa',
#   307: 'owen sound, ontario, canada',
#   308: 'redding, california, usa',
#   309: 'auburn, alabama, usa',
#   310: 'disputanta, virginia, usa',
#   311: 'spartanburg, south carolina, usa',
#   312: 'san bernardino, california, usa',
#   313: 'casper, wyoming, usa',
#   314: 'milpitas, california, usa',
#   315: 'bonn, nordrhein-westfalen, germany',
#   316: 'woodstock, georgia, usa',
#   317: 'firenze, toscana, italy',
#   318: 'carrollton, texas, usa',
#   319: 'brampton, ontario, canada',
#   320: 'porto, porto, portugal',
#   321: 'gilroy, california, usa',
#   322: 'bronx, new york, usa',
#   323: 'orange park, florida, usa',
#   324: 'keizer, oregon, usa',
#   325: 'chantilly, virginia, usa',
#   326: 'jersey city, new jersey, usa',
#   327: 'catlettsburg, kentucky, usa',
#   328: 'st. catharines, ontario, canada',
#   329: 'des moines, iowa, usa',
#   330: 'greencastle, pennsylvania, usa',
#   331: 'pasadena, california, usa',
#   332: 'forest grove, oregon, usa',
#   333: 'bourbonnais, illinois, usa',
#   334: 'glasgow, scotland, united kingdom',
#   335: 'iowa city, iowa, usa',
#   336: 'dortmund, nordrhein-westfalen, germany',
#   337: 'brookline, massachusetts, usa',
#   338: 'windsor, ontario, canada',
#   339: 'laval, quebec, canada',
#   340: 'milton, ontario, canada',
#   341: 'bonaire, georgia, usa',
#   342: 'vienna, vienna, austria',
#   343: 'hoover, alabama, usa',
#   344: 'freehold, new jersey, usa',
#   345: 'florence, alabama, usa',
#   346: 'canberra, australian capital territory, australia',
#   347: 'manistee, michigan, usa',
#   348: 'owings mills, maryland, usa',
#   349: 'greenville, texas, usa',
#   350: 'schenectady, new york, usa',
#   351: 'lancaster, pennsylvania, usa',
#   352: 'nottingham, england, united kingdom',
#   353: 'greensboro, north carolina, usa',
#   354: 'leuven, vlaams-brabant, belgium',
#   355: 'tustin, california, usa',
#   356: 'midland, texas, usa',
#   357: 'oakdale, california, usa',
#   358: 'burlington, vermont, usa',
#   359: 'escondido, california, usa',
#   360: 'ogden, utah, usa',
#   361: 'palmdale, california, usa',
#   362: 'hull, england, united kingdom',
#   363: 'saratoga, california, usa',
#   364: 'irvine, california, usa',
#   365: 'niskayuna, new york, usa',
#   366: 'harrisburg, pennsylvania, usa',
#   367: 'newport, rhode island, usa',
#   368: 'astoria, oregon, usa',
#   369: 'pawtucket, rhode island, usa',
#   370: 'blythewood, south carolina, usa',
#   371: 'ramah, new mexico, usa',
#   372: 'moberly, missouri, usa',
#   373: 'charlottesville, virginia, usa',
#   374: 'niagara falls, ontario, canada',
#   375: 'federal way, washington, usa',
#   376: 'apex, north carolina, usa',
#   377: 'scottsdale, arizona, usa',
#   378: 'danville, virginia, usa',
#   379: 'greenwood, south carolina, usa',
#   380: 'saginaw, michigan, usa',
#   381: 'gainesville, florida, usa',
#   382: 'blacksburg, virginia, usa',
#   383: 'peoria, arizona, usa',
#   384: 'fort myers, florida, usa',
#   385: 'st kilda, victoria, australia',
#   386: 'bartlesville, oklahoma, usa',
#   387: 'stockholm, stockholm, sweden',
#   388: 'coventry, england, united kingdom',
#   389: 'mentor, ohio, usa',
#   390: 'dripping springs, texas, usa',
#   391: 'rhame, north dakota, usa',
#   392: 'almada, setúbal, portugal',
#   393: 'nebraska city, nebraska, usa',
#   394: 'paradise, pennsylvania, usa',
#   395: 'lawrenceville, georgia, usa',
#   396: 'browns mills, new jersey, usa',
#   397: 'decatur, georgia, usa',
#   398: 'red deer, alberta, canada',
#   399: 'bloomington, indiana, usa',
#   400: 'kaneohe, hawaii, usa',
#   401: 'mobile, alabama, usa',
#   402: 'cedar rapids, iowa, usa',
#   403: 'navarre, florida, usa',
#   404: 'akron,, ohio, usa',
#   405: 'deland, florida, usa',
#   406: 'morris plains, new jersey, usa',
#   407: 'thunder bay, ontario, canada',
#   408: 'middletown, ohio, usa',
#   409: 'nahant, massachusetts, usa',
#   410: 'oceanside, california, usa',
#   411: 'covington, virginia, usa',
#   412: 'brisbane, queensland, australia',
#   413: 'saint louis, missouri, usa',
#   414: 'olive branch, mississippi, usa',
#   415: 'chatham, ontario, canada',
#   416: 'reston, virginia, usa',
#   417: 'manchester, connecticut, usa',
#   418: 'ramona, california, usa',
#   419: 'pueblo, colorado, usa',
#   420: 'dallas, georgia, usa',
#   421: 'overland park, kansas, usa',
#   422: 'nicholasville, kentucky, usa',
#   423: 'seixal, setúbal, portugal',
#   424: 'stamford, connecticut, usa',
#   425: 'ft huachuca, arizona, usa',
#   426: 'springfield, virginia, usa',
#   427: 'lansdale, pennsylvania, usa',
#   428: 'charlestown, massachusetts, usa',
#   429: 'henderson, nevada, usa',
#   430: 'fair oaks, california, usa',
#   431: 'ormond beach, florida, usa',
#   432: 'athens, georgia, usa',
#   433: 'yulee, florida, usa',
#   434: 'saint paul, minnesota, usa',
#   435: 'rural hall, north carolina, usa',
#   436: 'middletown, connecticut, usa',
#   437: 'pekin, illinois, usa',
#   438: 'st. petersburg, florida, usa',
#   439: 'dove canyon, california, usa',
#   440: 'bountiful, utah, usa',
#   441: 'warwick, rhode island, usa',
#   442: 'germantown, maryland, usa',
#   443: 'hamilton, ohio, usa',
#   444: 'butler, pennsylvania, usa',
#   445: 'carneys point, new jersey, usa',
#   446: 'sudbury, massachusetts, usa',
#   447: 'norwich, england, united kingdom',
#   448: 'cumming, georgia, usa',
#   449: 'roswell, georgia, usa',
#   450: 'west chester, pennsylvania, usa',
#   451: 'kensington, california, usa',
#   452: 'bay area, california, usa',
#   453: 'taneytown, maryland, usa',
#   454: 'redford, michigan, usa',
#   455: 'kingston, ontario, canada',
#   456: 'lake oswego, oregon, usa',
#   457: 'farmington hills, michigan, usa',
#   458: 'campbellsport, wisconsin, usa',
#   459: 'comanche, texas, usa',
#   460: 'newmarket, ontario, canada',
#   461: 'dunedin, otago, new zealand',
#   462: 'waianae, hawaii, us',
#   463: 'whitehorse, yukon territory, canada',
#   464: 'studio city, california, usa',
#   465: 'oviedo, florida, usa',
#   466: 'stratford, connecticut, usa',
#   467: 'lincoln, new brunswick, canada',
#   468: 'greenwood, british columbia, canada',
#   469: 'west bend, wisconsin, usa',
#   470: 'crescent city, florida, usa',
#   471: 'katy, texas, usa',
#   472: 'perth, western australia, australia',
#   473: 'atlantic highlands, new jersey, usa',
#   474: 'menasha, wisconsin, usa',
#   475: 'bremerton, washington, usa',
#   476: 'sonoma, california, usa',
#   477: 'baker city, oregon, usa',
#   478: 'syracuse, new york, usa',
#   479: 'strasbourg, alsace, france',
#   480: 'cortez, colorado, usa',
#   481: 'leeds, england, united kingdom',
#   482: 'douglasville, georgia, usa',
#   483: 'kamuela, hawaii, usa',
#   484: 'belton, texas, usa',
#   485: 'cottage grove, oregon, usa',
#   486: 'vienna, virginia, usa',
#   487: 'fishers, indiana, usa',
#   488: 'encinitas, california, usa',
#   489: 'cape girardeau, missouri, usa',
#   490: 'lacey, washington, usa',
#   491: 'west falls, new york, usa',
#   492: 'walnut creek, california, usa',
#   493: 'kingston, washington, usa',
#   494: 'sterling, virginia, usa',
#   495: 'lake mary, florida, usa',
#   496: 'lombard, illinois, usa',
#   497: 'westminster, maryland, usa',
#   498: 'fountain valley, california, usa',
#   499: 'kissimmee, florida, usa',
#   500: 'palm desert, california, usa',
#   501: 'warrensburg, missouri, usa',
#   502: 'bismarck, north dakota, usa',
#   503: 'cardiff, wales, united kingdom',
#   504: 'santa fe, new mexico, usa',
#   505: 'san ramon, california, usa',
#   506: 'littleton, colorado, usa',
#   507: 'lynbrook, new york, usa',
#   508: 'grove city, ohio, usa',
#   509: 'new britain, connecticut, usa',
#   510: 'rochester, minnesota, usa',
#   511: 'markham, ontario, canada',
#   512: 'enterprise, oregon, usa',
#   513: 'hooksett, new hampshire, usa',
#   514: 'new bern, north carolina, usa',
#   515: 'round lake, illinois, usa',
#   516: 'saint john, new brunswick, canada',
#   517: 'dandridge, tennessee, usa',
#   518: 'omemee, ontario, canada',
#   519: 'ploiesti, prahova, romania',
#   520: 'oxford, connecticut, usa',
#   521: 'grapevine, texas, usa',
#   522: 'bradenton, florida, usa',
#   523: 'metuchen, new jersey, usa',
#   524: 'kuala lumpur, kuala lumpur, malaysia',
#   525: 'dunnville, ontario, canada',
#   526: 'renton, washington, usa',
#   527: 'lisbon, lisbon, portugal',
#   528: 'cliffwood, new jersey, usa',
#   529: 'hi nella, new jersey, usa',
#   530: 'new albany, indiana, usa',
#   531: 'rennes, bretagne, france',
#   532: 'new milford, connecticut, usa',
#   533: 'fremont, california, usa',
#   534: 'pleasant hill, california, usa',
#   535: 'mackay, queensland, australia',
#   536: 'jonesboro, arkansas, usa',
#   537: 'bothell, washington, usa',
#   538: 'arlington heights, illinois, usa',
#   539: 'monett, missouri, usa',
#   540: 'sarasota, florida, usa',
#   541: 'walpole, massachusetts, usa',
#   542: 'north hollywood, california, usa',
#   543: 'petaling jaya, selangor, malaysia',
#   544: 'warren, new jersey, usa',
#   545: 'buffalo, new york, usa',
#   546: 'peterborough, ontario, canada',
#   547: 'zachary, louisiana, usa',
#   548: 'tübingen, baden-württemberg, germany',
#   549: 'frankfurt am main, hessen, germany',
#   550: 'mosinee, wisconsin, usa',
#   551: 'yucca valley, california, usa',
#   552: 'felixstowe, suffolk, united kingdom',
#   553: 'aptos, california, usa',
#   554: 'newbury park, california, usa',
#   555: 'elmhurst, illinois, usa',
#   556: 'delray beach, florida, usa',
#   557: 'hopewell junction, new york, usa',
#   558: 'quincy, massachusetts, usa',
#   559: 'grimes, iowa, usa',
#   560: 'elsmere, kentucky, usa',
#   561: 'manhattan, kansas, usa',
#   562: 'rio rancho, new mexico, usa',
#   563: 'plant city, florida, usa',
#   564: 'toccoa, ga., usa',
#   565: 'singapore, singapore, singapore',
#   566: 'hartford, connecticut, usa',
#   567: 'daly city, california, usa',
#   568: 'pinehurst, north carolina, usa',
#   569: 'dumont, new jersey, usa',
#   570: 'san luis obispo, california, usa',
#   571: 'albany, california, usa',
#   572: 'brighton, colorado, usa',
#   573: 'olney, maryland, usa',
#   574: 'largo, florida, usa',
#   575: 'west vancouver, british columbia, canada',
#   576: 'puyallup, washington, usa',
#   577: 'appleton, wisconsin, usa',
#   578: 'southampton, england, united kingdom',
#   579: 'sellersville, pennsylvania, usa',
#   580: 'lemon grove, california, usa',
#   581: 'evansville, indiana, usa',
#   582: 'the woodlands, texas, usa',
#   583: 'slidell, louisiana, usa',
#   584: 'redwood city, california, usa',
#   585: 'billings, montana, usa',
#   586: 'santa barbara, california, usa',
#   587: 'clearwater, florida, usa',
#   588: '., kansas, usa',
#   589: 'worcester, massachusetts, usa',
#   590: 'urbana, illinois, usa',
#   591: 'longmont, colorado, usa',
#   592: 'niceville, florida, usa',
#   593: 'aiken, south carolina, usa',
#   594: 'burien, washington, usa',
#   595: 'columbus (grandview heights), ohio, usa',
#   596: 'woodbridge, virginia, usa',
#   597: 'boyce, virginia, usa',
#   598: 'duisburg, nordrhein-westfalen, germany',
#   599: 'sydenham, london, england, united kingdom',
#   600: 'braunschweig, niedersachsen, germany',
#   601: 'dyersburg, tennessee, usa',
#   602: 'winfield, alberta, canada',
#   603: 'woodbine, maryland, usa',
#   604: 'mililani, hawaii, usa',
#   605: 'altoona, iowa, usa',
#   606: 'kuala lumpur, wilayah persekutuan, malaysia',
#   607: 'kennesaw, georgia, usa',
#   608: 'lafayette, indiana, usa',
#   609: 'fort wayne, indiana, usa',
#   610: 'yuba city, california, usa',
#   611: 'west linn, oregon, usa',
#   612: 'scarborough, ontario, canada',
#   613: 'auburndale, massachusetts, usa',
#   614: 'chicago heights, illinois, usa',
#   615: 'hillsboro, oregon, usa',
#   616: 'jackson, tennessee, usa',
#   617: 'medford, new york, usa',
#   618: 'normal, illinois, usa',
#   619: 'seal beach, california, usa',
#   620: 'jacksonville, north carolina, usa',
#   621: 'coquitlam, british columbia, canada',
#   622: 'green bay, wisconsin, usa',
#   623: 'catonsville, maryland, usa',
#   624: 'arcata, california, usa',
#   625: 'whitney, texas, usa',
#   626: 'langley, british columbia, canada',
#   627: 'regensburg, bavaria, germany',
#   628: 'west kensington, london, united kingdom',
#   629: 'abertillery, wales, united kingdom',
#   630: 'amagansett, new york, usa',
#   631: 'white plains, new york, usa',
#   632: 'springfield, oregon, usa',
#   633: 'walla walla, washington, usa',
#   634: 'salem, oregon, usa',
#   635: 'legazpi, albay, philippines',
#   636: 'annapolis, maryland, usa',
#   637: 'boulder city, nevada, usa',
#   638: 'holybourne, england, united kingdom',
#   639: 'lockport, new york, usa',
#   640: 'medford, oregon, usa',
#   641: 'moore, oklahoma, usa',
#   642: 'menomonie, wisconsin, usa',
#   643: 'hendersonville, north carolina, usa',
#   644: 'bolingbrook, illinois, usa',
#   645: 'o`fallon, missouri, usa',
#   646: 'waipahu, hawaii, usa',
#   647: 'aloha, oregon, usa',
#   648: 'plantersville, texas, usa',
#   649: 'west palm beach, florida, usa',
#   650: 'spruce grove, alberta, canada',
#   651: 'naperville, illinois, usa',
#   652: 'chattanooga, tennessee, usa',
#   653: 'rainsville, alabama, usa',
#   654: 'yuma, arizona, usa',
#   655: 'albq, new mexico, usa',
#   656: 'boca raton, florida, usa',
#   657: 'klang, selangor, malaysia',
#   658: 'jackson heights, new york, usa',
#   659: 'michie, tennessee, usa',
#   660: 'webster, new york, usa',
#   661: 'saint clair, michigan, usa',
#   662: 'elk  city, oklahoma, usa',
#   663: 'king of prussia, pennsylvania, usa',
#   664: 'gig harbor, washington, usa',
#   665: 'davis, california, usa',
#   666: 'manchester, england, united kingdom',
#   667: 'perry, new york, usa',
#   668: 'abilene, texas, usa',
#   669: 'apo, ae, usa',
#   670: 'freiburg, baden-württemberg, germany',
#   671: 'north york, ontario, canada',
#   672: 'stockton, california, usa',
#   673: 'aurora, illinois, usa',
#   674: 'potomac falls, virginia, usa',
#   675: 'lake country, british columbia, canada',
#   676: 'waldorf, maryland, usa',
#   677: 'belvidere, illinois, usa',
#   678: 'arab, alabama, usa',
#   679: 'conway, arkansas, usa',
#   680: 'merrick, acworth, new york, georgia, usa',
#   681: 'framingham, massachusetts, usa',
#   682: 'northridge, california, usa',
#   683: 'north reading, massachusetts, usa',
#   684: 'crest hill, illinois, usa',
#   685: 'west lafayette, indiana, usa',
#   686: 'anaheim, california, usa',
#   687: 'west blocton, alabama, usa',
#   688: 'bethlehem, pennsylvania, usa',
#   689: 'lancaster, ohio, usa',
#   690: 'elmira, new york, usa',
#   691: 'nanaimo, british columbia, canada',
#   692: 'altamonte springs, florida, usa',
#   693: 'frisco, texas, usa',
#   694: 'köln, nordrhein-westfalen, germany',
#   695: 'ruma, illinois, usa',
#   696: 'mooresville, north carolina, usa',
#   697: 'catawba, wisconsin, usa',
#   698: 'riverside, california, usa',
#   699: 'rock hill, south carolina, usa',
#   700: 'richmond, california, usa',
#   701: 'trois-rivières ouest, quebec, canada',
#   702: 'whitby, ontario, canada',
#   703: 'morgan hill, california, usa',
#   704: 'westchester, illinois, usa',
#   705: 'methuen, massachusetts, usa',
#   706: 'hollywood, maryland, usa',
#   707: 'montrose, california, usa',
#   708: 'edinburgh, scotland, united kingdom',
#   709: 'new port richey, florida, usa',
#   710: 'poway, california, usa',
#   711: 'santa clara, california, usa',
#   712: 'independence, west virginia, usa',
#   713: 'mannford, oklahoma, usa',
#   714: 'livingston, texas, usa',
#   715: 'petaluma, california, usa',
#   716: 'tomball, texas, usa',
#   717: 'ithaca, new york, usa',
#   718: 'petersburg, virginia, usa',
#   719: 'cross plains, wisconsin, usa',
#   720: 'towson, maryland, usa',
#   721: 'pensacola, florida, usa',
#   722: 'espoo, uusimaa, finland',
#   723: 'elizabeth city, north carolina, usa',
#   724: 'jacksonville beach, florida, usa',
#   725: 'los banos, california, usa',
#   726: 'cave creek, arizona, usa',
#   727: 'albany, oregon, usa',
#   728: 'franklin, tennessee, usa',
#   729: 'southfield, michigan, usa',
#   730: 'hickory, mississippi, usa',
#   731: 'the dalles, oregon, usa',
#   732: 'temecula, california, usa',
#   733: 'sierra madre, california, usa',
#   734: 'shah alam, selangor, malaysia',
#   735: 'long island, new york, usa',
#   736: 'eagan, minnesota, usa',
#   737: 'westminster, colorado, usa',
#   738: 'emporia, kansas, usa',
#   739: 'darlington, south carolina, usa',
#   740: 'wilmington, massachusetts, usa',
#   741: 'warrenton, virginia, usa',
#   742: 'montgomery, alabama, usa',
#   743: 'lakewood, california, usa',
#   744: 'allen park, michigan, usa',
#   745: 'ocala, florida, usa',
#   746: 'lake worth, florida, usa',
#   747: 'tempe, arizona, usa',
#   748: 'mason, ohio, usa',
#   749: 'highland, california, usa',
#   750: 'st catharines, ontario, canada',
#   751: 'tampere, pirkanmaa, finland',
#   752: 'lakewood, washington, usa',
#   753: 'chisholm, minnesota, usa',
#   754: 'san angelo, texas, usa',
#   755: 'stuttgart, baden-wuerttemberg, germany',
#   756: 'dartmouth, nova scotia, canada',
#   757: 'struthers, ohio, usa',
#   758: 'napa, california, usa',
#   759: 'richmond, kentucky, usa',
#   760: 'florence, oregon, usa',
#   761: 'lima, ohio, usa',
#   762: 'york, pennsylvania, usa',
#   763: 'st. john`s, ontario, canada',
#   764: 'brookfield, wisconsin, usa',
#   765: 'barreiro, barreiro, portugal',
#   766: 'glendora, california, usa',
#   767: 'loveland, colorado, usa',
#   768: 'suffolk, virginia, usa',
#   769: 'lubbock, texas, usa',
#   770: 'günzburg, bayern, germany',
#   771: 'dublin, dublin, ireland',
#   772: 'kingsport, tennessee, usa',
#   773: 'doha, doha, qatar',
#   774: 'lancaster, california, usa',
#   775: 'juneau, alaska, usa',
#   776: 'seadrift, texas, usa',
#   777: 'umatilla, oregon, usa',
#   778: 'shrewsbury, massachusetts, usa',
#   779: 'castleton, vermont, usa',
#   780: 'trenton, ontario, canada',
#   781: 'newark, delaware, usa',
#   782: 'dekalb, illinois, usa',
#   783: 'camarillo, california, usa',
#   784: 'cherry hill, new jersey, usa',
#   785: 'derby, england, united kingdom',
#   786: 'rohnert park, california, usa',
#   787: 'norman, oklahoma, usa',
#   788: 'st-légier, vaud, switzerland',
#   789: 'aachen, nordrhein-westfalen, germany',
#   790: 'arlington, tennessee, usa',
#   791: 'round rock, texas, usa',
#   792: 'isle of palms, south carolina, usa',
#   793: 'chamblee, georgia, usa',
#   794: 'hillsborough, new jersey, usa',
#   795: 'naples, florida, usa',
#   796: 'paullina, iowa, usa',
#   797: 'florence, arizona, usa',
#   798: 'janesville, wisconsin, usa',
#   799: 'sudbury, ontario, canada',
#   800: 'davenport, iowa, usa',
#   801: 'beacon, new york, usa',
#   802: 'mcallen, texas, usa',
#   803: 'st. marys, georgia, usa',
#   804: 'wake forest, north carolina, usa',
#   805: 'tonawanda, new york, usa',
#   806: 'ruby, south carolina, usa',
#   807: 'fall river, massachusetts, usa',
#   808: 'st. thomas, ontario, canada',
#   809: 'la jolla, california, usa',
#   810: 'calverton, new york, usa',
#   811: 'manila, makati, phillipines',
#   812: 'quezon city, manila, philippines',
#   813: 'thompson, manitoba, canada',
#   814: 'new castle, delaware, usa',
#   815: 'madera, california, usa',
#   816: 'chardon, ohio, usa',
#   817: 'kernersville, north carolina, usa',
#   818: 'beaver dams, new york, usa',
#   819: 'ada, michigan, usa',
#   820: 'rochester, michigan, usa',
#   821: 'trabuco canyon, california, usa',
#   822: 'east lansing, michigan, usa',
#   823: 'st. john`s, newfoundland, canada',
#   824: 'destrehan, louisiana, usa',
#   825: 'zaragoza, aragón, spain',
#   826: 'mainz, rheinland-pfalz, germany',
#   827: 'haskell, new jersey, usa',
#   828: 'richmond, british columbia, canada',
#   829: 'herne bay, england, united kingdom',
#   830: 'santa clarita, california, usa',
#   831: 'san gabriel, california, usa',
#   832: 'courtenay, british columbia, canada',
#   833: 'east elmhurst, new york, usa',
#   834: 'norwood, massachusetts, usa',
#   835: 'corpus christi, texas, usa',
#   836: 'basel, basel-stadt, switzerland',
#   837: 'ashland, missouri, usa',
#   838: 'west columbia, south carolina, usa',
#   839: 'bloomsburg, pennsylvania, usa',
#   840: 'terre haute, indiana, usa',
#   841: 'columbiana, alabama, usa',
#   842: 'costa de caparica, lisbon, portugal',
#   843: 'nisswa, minnesota, usa',
#   844: 'binghamton, new york, usa',
#   845: 'kingsville, texas, usa',
#   846: 'weaverville, california, usa',
#   847: 'madison, new jersey, usa',
#   848: 'plymouth, indiana, usa',
#   849: 'glen allen, virginia, usa',
#   850: 'lille, nord, france',
#   851: 'atlantic beach, florida, usa',
#   852: 'kent, washington, usa',
#   853: 'festus, missouri, usa',
#   854: 'brantford, ontario, canada',
#   855: 'central sq., new york, usa',
#   856: 'hazelwood, missouri, usa',
#   857: 'duluth, georgia, usa',
#   858: 'fontana, california, usa',
#   859: 'orillia, ontario, canada',
#   860: 'fairview, new jersey, usa',
#   861: 'nottingham, maryland, usa',
#   862: 'tuscaloosa, alabama, usa',
#   863: 'edmond, oklahoma, usa',
#   864: 'brighton, massachusetts, usa',
#   865: 'eufaula, alabama, usa',
#   866: 'adrian, michigan, usa',
#   867: 'south ohio, nova scotia, canada',
#   868: 'santander, cantabria, spain',
#   869: 'bainbridge island, washington, usa',
#   870: 'mission hills, california, usa',
#   871: 'rockville, maryland, usa',
#   872: 'regensburg, bayern, germany',
#   873: 'lake george, new york, usa',
#   874: 'sant cugat del vallès, catalunya, spain',
#   875: 'some other, planet, far away...',
#   876: 'wokingham, berkshire, united kingdom',
#   877: 'oro valley, arizona, usa',
#   878: 'easley, south carolina, usa',
#   879: 'allston, massachusetts, usa',
#   880: 'winston-salem, north carolina, usa',
#   881: 'richmond hill, ontario, canada',
#   882: 'marshfield, massachusetts, usa',
#   883: 'clinton twp., michigan, usa',
#   884: 'owensboro, kentucky, usa',
#   885: 'rock island, illinois, usa',
#   886: 'dover-foxcroft, maine, usa',
#   887: 'barnhart, missouri, usa',
#   888: 'derby, kansas, usa',
#   889: 'royal oak, michigan, usa',
#   890: 'circleville, ohio, usa',
#   891: 'penticton, british columbia, canada',
#   892: 'scott, arkansas, usa',
#   893: 'newport news, virginia, usa',
#   894: 'orem, utah, usa',
#   895: 'salem, ohio, usa',
#   896: 'wokingham, england, united kingdom',
#   897: 'brentwood, california, usa',
#   898: 'el segundo, california, usa',
#   899: 'mokena, illinois, usa',
#   900: 'benbrook, texas, usa',
#   901: 'shreveport, louisiana, usa',
#   902: 'hackettstown, new jersey, usa',
#   903: 'manassas, virginia, usa',
#   904: 'hesperia, california, usa',
#   905: 'streamwood, illinois, usa',
#   906: 'pickering, ontario, canada',
#   907: 'duchesne, utah, usa',
#   908: 'sugar land, texas, usa',
#   909: 'redmond, washington, usa',
#   910: 'winter park, florida, usa',
#   911: 'wangen, zürich, switzerland',
#   912: 'minot, north dakota, usa',
#   913: 'chesterfield, missouri, usa',
#   914: 'lyon, rhône-alpes, france',
#   915: 'new westminster, british columbia, canada',
#   916: 'zaragoza, zaragoza, spain',
#   917: 'leipzig, sachsen, germany',
#   918: 'milano, lombardia, italy',
#   919: 'w.m., pennsylvania, usa',
#   920: 'lake wales, florida, usa',
#   921: 'katonah, new york, usa',
#   922: 'edinburg, texas, usa',
#   923: 'oshawa, ontario, canada',
#   924: 'greenbelt, maryland, usa',
#   925: 'pewaukee, wisconsin, usa',
#   926: 'elkhorn, nebraska, usa',
#   927: 'wellesley, massachusetts, usa',
#   928: 'grand prairie, texas, usa',
#   929: 'sheldon, iowa, usa',
#   930: 'watervliet, new york, usa',
#   931: 'pgh, pennsylvania, usa',
#   932: 'geismar, louisiana, usa',
#   933: 'northbrook, illinois, usa',
#   934: 'bloomfield, new jersey, usa',
#   935: 'smyrna, georgia, usa',
#   936: 'leeds, alabama, usa',
#   937: 'carbondale, illinois, usa',
#   938: 'arlington, massachusetts, usa',
#   939: 'clark fork, idaho, usa',
#   940: 'brights grove, ontario, canada',
#   941: 'edwardsville, illinois, usa',
#   942: 'greenville, north carolina, usa',
#   943: 'fairfield, california, usa',
#   944: 'pottstown, pennsylvania, usa',
#   945: 'oakville, ontario, canada',
#   946: 'harper woods, michigan, usa',
#   947: 'danville, california, usa',
#   948: 'barrie, ontario, canada',
#   949: 'verdon, nebraska, usa',
#   950: 'crystal lake, illinois, usa',
#   951: 'sabine pass, texas, usa',
#   952: 'st paul, minnesota, usa',
#   953: 'ft myers beach, florida, usa',
#   954: 'denton, texas, usa',
#   955: 'keyser, west virginia, usa',
#   956: 'lethbridge, alberta, canada',
#   957: 'downieville, california, usa',
#   958: 'san mateo, california, usa',
#   959: 'lock haven, pennsylvania, usa',
#   960: 'dunedin, florida, usa',
#   961: 'sterling heights, michigan, usa',
#   962: 'riedstadt, hessen, germany',
#   963: 'geneva, illinois, usa',
#   964: 'brookville, pennsylvania, usa',
#   965: 'livingston, new jersey, usa',
#   966: 'homer, alaska, usa',
#   967: 'coventry, connecticut, usa',
#   968: 'winder, georgia, usa',
#   969: 'wasilla, alaska, usa',
#   970: 'karlsruhe, baden-wuerttemberg, germany',
#   971: 'toulouse, haute-garonne, france',
#   972: 'wesley chapel, florida, usa',
#   973: 'berck sur mer, pas de calais, france',
#   974: 'hickory, north carolina, usa',
#   975: 'shingle springs, california, usa',
#   976: 'carbonear, newfoundland, canada',
#   977: 'beaverton, ontario, canada',
#   978: 'roma, lazio, italy',
#   979: 'powys, wales, united kingdom',
#   980: 'richboro, pennsylvania, usa',
#   981: 'fpo, ap, okinawa, japan',
#   982: 'mechanicsburg, pennsylvania, usa',
#   983: 'kuala lumpur, selangor, malaysia',
#   984: 'rockford, illinois, usa',
#   985: 'sheffield, england, united kingdom',
#   986: 'sheboygan, wisconsin, usa',
#   987: 'wickenburg, arizona, usa',
#   988: 'glendale heights, illinois, usa',
#   989: 'upper township, new jersey, usa',
#   990: 'ionia, michigan, usa',
#   991: 'springdale, arkansas, usa',
#   992: 'north avoca, new south wales, australia',
#   993: 'southgate, michigan, usa',
#   994: 'fair haven, michigan, usa',
#   995: 'pomfret center, connecticut, usa',
#   996: 'soddy-daisy, tennessee, usa',
#   997: 'medina, ohio, usa',
#   998: 'conroe, texas, usa',
#   999: 'bellevue, nebraska, usa',
#   ...},
#  'publisher': {0: 'Ballantine Books',
#   1: 'Pocket',
#   2: 'Berkley Publishing Group',
#   3: 'Warner Books',
#   4: 'Bantam',
#   5: 'Signet Book',
#   6: 'Bantam Books',
#   7: 'Avon',
#   8: 'Penguin Books',
#   9: 'Perennial',
#   10: 'Jove Books',
#   11: 'Dell',
#   12: 'HarperTorch',
#   13: 'Vintage Books USA',
#   14: 'Dell Publishing Company',
#   15: 'Fawcett Books',
#   16: 'Scholastic',
#   17: 'Scribner',
#   18: 'Little, Brown',
#   19: "St. Martin's Press",
#   20: 'Del Rey Books',
#   21: 'Simon & Schuster',
#   22: "St. Martin's Paperbacks",
#   23: 'Harlequin',
#   24: 'Mira',
#   25: 'Plume Books',
#   26: 'Anchor',
#   27: 'Tor Books',
#   28: 'Vintage',
#   29: 'Warner Vision',
#   30: 'Doubleday',
#   31: 'HarperTrophy',
#   32: 'Viking Books',
#   33: 'Ace Books',
#   34: 'HarperCollins',
#   35: 'Silhouette',
#   36: 'Back Bay Books',
#   37: 'Putnam Publishing Group',
#   38: 'Del Rey',
#   39: 'Hyperion',
#   40: 'Washington Square Press',
#   41: 'Ivy Books',
#   42: 'Harvest Books',
#   43: 'Riverhead Books',
#   44: 'Touchstone',
#   45: 'Random House Inc',
#   46: 'Alfred A. Knopf',
#   47: 'Andrews McMeel Publishing',
#   48: 'Random House',
#   49: 'Delta',
#   50: 'Pocket Star',
#   51: 'Tyndale House Publishers',
#   52: 'Health Communications',
#   53: 'Doubleday Books',
#   54: 'Delacorte Press',
#   55: 'Putnam Pub Group',
#   56: 'Daw Books',
#   57: 'Star Trek',
#   58: 'Regan Books',
#   59: 'Harpercollins',
#   60: 'HarperCollins Publishers',
#   61: 'Pocket Books',
#   62: 'Avon Books',
#   63: 'Anchor Books/Doubleday',
#   64: 'Penguin USA',
#   65: 'Knopf',
#   66: 'Broadway Books',
#   67: 'Tor Fantasy',
#   68: 'Penguin Books Ltd',
#   69: 'Picador USA',
#   70: 'Picador',
#   71: 'Bantam Doubleday Dell',
#   72: 'Eos',
#   73: 'Dutton Books',
#   74: 'Onyx Books',
#   75: 'Dover Publications',
#   76: 'William Morrow & Company',
#   77: 'Atria',
#   78: "St. Martin's Griffin",
#   79: 'Leisure Books',
#   80: 'Spectra Books',
#   81: 'Laure Leaf',
#   82: 'Puffin Books',
#   83: 'Simon Pulse',
#   84: 'William Morrow',
#   85: 'Harcourt',
#   86: 'Roc',
#   87: 'Bantam Dell Pub Group',
#   88: 'Broadway',
#   89: 'Grove Press',
#   90: 'Houghton Mifflin Company',
#   91: 'Zebra Books',
#   92: 'Island',
#   93: 'Yearling',
#   94: 'New Amer Library',
#   95: "G. P. Putnam's Sons",
#   96: 'NTC/Contemporary Publishing Company',
#   97: 'Vintage Books',
#   98: 'Goldmann',
#   99: 'Yearling Books',
#   100: 'Baen',
#   101: 'Too Far',
#   102: 'Harper Mass Market Paperbacks (Mm)',
#   103: 'Red Dress Ink',
#   104: 'Love Spell',
#   105: 'Penguin Putnam~mass',
#   106: 'ACE Charter',
#   107: "Random House Children's Books",
#   108: 'HarperSanFrancisco',
#   109: 'Penguin USA (Paper)',
#   110: 'Henry Holt & Company',
#   111: 'Random House Trade',
#   112: 'Fawcett',
#   113: 'Fireside',
#   114: 'Signet Classics',
#   115: 'Chronicle Books',
#   116: 'W. W. Norton & Company',
#   117: 'Bantam Classics',
#   118: 'Arthur A. Levine Books',
#   119: 'New American Library',
#   120: 'Trafalgar Square',
#   121: 'Wizards of the Coast',
#   122: 'Kensington Publishing Corporation',
#   123: 'Mira Books',
#   124: 'Random House Books for Young Readers',
#   125: 'Little Brown & Company',
#   126: 'Distribooks Inc',
#   127: 'Workman Publishing',
#   128: 'Avon Trade',
#   129: 'Laurel Leaf',
#   130: 'Little Brown & Co',
#   131: 'Pantheon Books',
#   132: 'Villard Books',
#   133: 'Heyne',
#   134: 'Spectra',
#   135: 'Aladdin',
#   136: 'Llewellyn Publications',
#   137: 'Three Rivers Press',
#   138: 'Free Press',
#   139: 'Bantam Dell Publishing Group',
#   140: 'Scholastic Paperbacks',
#   141: 'Owl Books',
#   142: 'Little Brown and Company',
#   143: 'Nan A. Talese',
#   144: 'Prentice Hall (K-12)',
#   145: 'Hyperion Press',
#   146: 'Pinnacle Books',
#   147: "St. Martin's Minotaur",
#   148: 'Plume',
#   149: 'LÃ?Â¼bbe',
#   150: 'Multnomah',
#   151: 'Pan Books Ltd',
#   152: 'Miramax Kids',
#   153: 'Oxford University Press',
#   154: 'Penguin Putnam',
#   155: 'Simon Spotlight Entertainment',
#   156: 'W.W. Norton & Company',
#   157: 'St Martins Pr',
#   158: 'Penguin Putnam~trade',
#   159: 'LGF',
#   160: 'Scholastic Inc',
#   161: 'Miramax',
#   162: 'Distribooks',
#   163: 'Farrar Straus Giroux',
#   164: 'DC Comics',
#   165: 'Diogenes Verlag',
#   166: 'Bethany House Publishers',
#   167: 'Golden Books',
#   168: 'Crimeline',
#   169: 'Hyperion Books',
#   170: 'Mariner Books',
#   171: 'Random House Trade Paperbacks',
#   172: 'Atria Books',
#   173: 'Crown',
#   174: 'Dtv',
#   175: 'Harper Mass Market Paperbacks',
#   176: 'Warner Forever',
#   177: 'Perennial Currents',
#   178: 'Replica Books',
#   179: 'Pub Group West',
#   180: 'Villard',
#   181: 'Grosset & Dunlap',
#   182: 'Rowohlt Tb.',
#   183: 'Farrar, Straus and Giroux',
#   184: 'Houghton Mifflin',
#   185: 'MacMillan Publishing Company.',
#   186: 'Knopf Books for Young Readers',
#   187: 'Prime Crime',
#   188: 'HarperEntertainment',
#   189: 'Tor Books (Mm)',
#   190: 'Tor Science Fiction',
#   191: 'Laurel',
#   192: 'Not Avail',
#   193: 'Signet',
#   194: 'Warner Books Inc',
#   195: 'Steeple Hill',
#   196: 'Warner Books (Mm)',
#   197: 'Black Swan',
#   198: 'McGraw-Hill',
#   199: 'Gallimard',
#   200: 'Forge Books',
#   201: 'Zondervan Publishing Company',
#   202: 'Pantheon',
#   203: 'Downtown Press',
#   204: 'John Wiley & Sons Inc',
#   205: 'Warner Books> C/o Little Br',
#   206: 'Atlantic Monthly Press',
#   207: 'Piper',
#   208: 'Three Rivers Press (CA)',
#   209: 'HarperTempest',
#   210: 'Farrar Straus & Giroux',
#   211: 'Perigee Trade',
#   212: 'Dial Books',
#   213: 'Troll Communications',
#   214: 'Forge',
#   215: 'HarperBusiness',
#   216: 'Delacorte Books for Young Readers',
#   217: 'MacAdam/Cage Publishing',
#   218: 'ReganBooks',
#   219: 'Scholastic Paperbacks (Mm)',
#   220: 'BRAVA',
#   221: 'Pan Macmillan',
#   222: 'Topaz',
#   223: 'Fischer (Tb.), Frankfurt',
#   224: 'Houghton Mifflin Co',
#   225: 'Starfire',
#   226: 'TSR',
#   227: 'Mysterious Press',
#   228: "J'ai lu",
#   229: 'Scribner Paper Fiction',
#   230: 'Aspect',
#   231: 'Laurel-Leaf Books',
#   232: 'Picador (UK)',
#   233: 'Algonquin Books of Chapel Hill',
#   234: 'Amber-Allen Publishing',
#   235: 'Crown Publishing Group (NY)',
#   236: 'MTV',
#   237: 'Workman Pub Co',
#   238: 'Ten Speed Press',
#   239: 'Fourth Estate',
#   240: 'Crossway Books',
#   241: 'Orb Books',
#   242: 'Candlewick Press (MA)',
#   243: 'Quill',
#   244: 'Gotham Books',
#   245: 'Putnam Pub Group (Paper)',
#   246: 'Farrar, Straus and Giroux (BYR)',
#   247: 'Ecco',
#   248: 'New Amer Library (Mm)',
#   249: 'Adams Media Corporation',
#   250: 'Main Street Books',
#   251: 'Wings',
#   252: 'Thomas Dunne Books',
#   253: 'Harpercollins Juvenile Books',
#   254: 'Faber Faber Inc',
#   255: 'Delta Trade Paperbacks',
#   256: 'Random House Childrens Books',
#   257: 'Running Press Book Publishers',
#   258: 'Jove Pubns',
#   259: 'Scholastic Point',
#   260: 'Rodale Books',
#   261: 'Thomas Nelson',
#   262: 'Abacus',
#   263: 'Modern Library',
#   264: 'Putnam Adult',
#   265: 'Crown Publishers',
#   266: 'Harmony',
#   267: 'Simon & Schuster (Trade Division)',
#   268: 'Metropolitan Books',
#   269: 'Del Sol Press',
#   270: 'Dorchester Publishing Company',
#   271: 'Jeremy P. Tarcher',
#   272: 'HCI',
#   273: 'Flamingo',
#   274: 'Andrews McMeel Pub',
#   275: 'Smithmark Pub',
#   276: 'New Directions Publishing Corporation',
#   277: 'Fanfare',
#   278: 'Dell Publishing',
#   279: 'Planeta Pub Corp',
#   280: 'Anagrama',
#   281: 'Macmillan Pub Ltd',
#   282: 'Apple',
#   283: 'Speak',
#   284: 'Diogenes Verlag AG',
#   285: 'Conari Press',
#   286: 'Lectorum Publications',
#   287: 'Celestial Arts',
#   288: 'Orion mass market paperback',
#   289: 'Bridge Publications',
#   290: 'Worldwide Library',
#   291: 'Gallimard Jeunesse',
#   292: 'Lb May & Assoc Inc',
#   293: 'Berkley Pub Group',
#   294: 'Shambhala',
#   295: 'WestBow Press',
#   296: 'New Amer Library Classics',
#   297: 'Perennial Classics',
#   298: 'Carlsen Verlag GmbH',
#   299: 'Albert Whitman & Company',
#   300: 'Punto de Lectura',
#   301: "Distribooks Int'l+inc",
#   302: 'Selldowns/no More Orders',
#   303: 'Harpercollins Publisher',
#   304: 'Pleasant Company Publications',
#   305: 'Bethany House',
#   306: 'St Martins Press',
#   307: 'Suhrkamp',
#   308: 'Hay House',
#   309: 'Owl Books (NY)',
#   310: 'Canongate Books',
#   311: 'Wilhelm Goldmann Verlag, GmbH',
#   312: 'St Martins Pr (Mm)',
#   313: 'Rayo',
#   314: 'Droemersche Verlagsanstalt Th. Knaur Nachf., GmbH & Co.',
#   315: 'Harper SanFrancisco',
#   316: 'Zebra Books (Mass Market)',
#   317: 'Anchor (UK)',
#   318: 'Perseus Books Group',
#   319: 'Riverhead Hardcover',
#   320: 'Perigee Books',
#   321: 'STRAPLESS',
#   322: 'New World Library',
#   323: 'Aufbau Tb',
#   324: 'Livre De Poche French',
#   325: 'Bloomsbury USA',
#   326: 'Magic Carpet Books',
#   327: 'Dutton Adult',
#   328: 'W Publishing Group',
#   329: 'Meredith Books',
#   330: 'Penguin Putnam Books for Young Readers',
#   331: 'University of Chicago Press',
#   332: 'Harpercollins Uk',
#   333: 'Minotauro',
#   334: 'HCI Teens',
#   335: 'Black Swan Books, Limited',
#   336: 'Plaza & Janes Editores, S.A.',
#   337: 'Random House Value Publishing',
#   338: 'Outlet Books Company',
#   339: 'Aladdin Library',
#   340: 'Scholastic Ltd',
#   341: 'Grove/Atlantic',
#   342: 'Beacon Press',
#   343: 'Anchor Pub',
#   344: 'Thomas Nelson Inc',
#   345: 'Stoddart+publishing',
#   346: 'Soho Press',
#   347: 'Methuen Publishing Ltd',
#   348: 'Pan Publishing',
#   349: 'Seal Press (WA)',
#   350: 'Harvest House Publishers',
#   351: "Simon & Schuster Children's Publishing",
#   352: 'btb',
#   353: 'Scholastic Paperbacks (T)',
#   354: 'Rutledge Hill Press',
#   355: 'Santillana USA Publishing Company',
#   356: 'Sagebrush Bound',
#   357: 'Sweet Valley',
#   358: 'Donald M. Grant/Scribner',
#   359: 'W W Norton & Co Inc',
#   360: 'Gallimard French',
#   361: 'Seven Stories Press',
#   362: 'Island Books',
#   363: 'Wordsworth Editions Ltd',
#   364: 'Little Apple',
#   365: 'Hazelden Publishing & Educational Services',
#   366: 'Folio',
#   367: 'Mandarin',
#   368: 'Ebury Press',
#   369: 'Point Fantasy',
#   370: "Harcourt Children's Books",
#   371: 'Harmony Books',
#   372: 'Tokyopop',
#   373: 'HarperFestival',
#   374: 'New Canadian Library',
#   375: 'Harpercollins Childrens Books',
#   376: 'Silhouette Books',
#   377: 'Henry Holt and Co.',
#   378: 'Firefly Books Ltd',
#   379: 'Simon Schuster Trade',
#   380: 'City Lights Publishers',
#   381: "O'Reilly",
#   382: 'Hyperion Books for Children',
#   383: 'Random House Value Pub',
#   384: 'Prima Lifestyles',
#   385: 'Skylark',
#   386: 'Sourcebooks',
#   387: 'Shaye Areheart Books',
#   388: 'Barbour Publishing',
#   389: 'Orion Publishing Group',
#   390: 'Btb Bei Goldmann',
#   391: 'Fischer Taschenbuch Verlag',
#   392: 'TokyoPop',
#   393: 'Firebird Distributing',
#   394: 'University of New Mexico Press',
#   395: 'Wildcat Canyon Press',
#   396: 'Ediciones B',
#   397: "Reader's Digest Association",
#   398: 'Random House~trade',
#   399: 'Judy Piatkus Publishers Ltd',
#   400: 'Xlibris Corporation',
#   401: 'Editions 10/18',
#   402: 'Actes Sud',
#   403: 'Gulliver Books Paperbacks',
#   404: 'Gramercy',
#   405: 'Faber & Faber',
#   406: 'Broadman & Holman Publishers',
#   407: 'White Wolf Games Studio',
#   408: 'Continental Book Company',
#   409: 'Harcourt Paperbacks',
#   410: 'Dial Press',
#   411: 'Reclam, Leipzig',
#   412: 'Kiepenheuer & Witsch',
#   413: 'Douglas & McIntyre',
#   414: 'Saint Jude Media',
#   415: "Editions J'Ai Lu",
#   416: 'Alianza',
#   417: 'Penguin Uk',
#   418: 'Virago Press (UK)',
#   419: 'Tusquets',
#   420: 'Consortium Book Sales & Dist',
#   421: 'Learning Curve',
#   422: 'Planeta',
#   423: 'Moody Publishers',
#   424: 'Addison Wesley Publishing Company',
#   425: 'Kiepenheuer & Witsch GmbH & Co. KG, Verlag',
#   426: 'Schoenhof Foreign Books Inc',
#   427: 'Albin Michel',
#   428: 'Cliff Street Books',
#   429: 'Plough Publishing House',
#   430: 'Harpertorch',
#   431: 'Talk Miramax Books',
#   432: 'McClelland & Stewart',
#   433: 'North Point Press',
#   434: 'Papier-Mache Press',
#   435: 'Citadel Press',
#   436: 'Alfaguara Ediciones, S.A. (Spain)',
# ...
#   958: 'bryant',
#   959: 'lethbridge',
#   960: 'keyser',
#   961: 'mechanicsburg',
#   962: 'wickenburg',
#   963: 'winder',
#   964: 'sabine pass',
#   965: 'chevy chase',
#   966: 'crystal lake',
#   967: 'lock haven',
#   968: 'carbonear',
#   969: 'portsmouth',
#   970: 'brookville',
#   971: 'powys',
#   972: 'st paul',
#   973: 'marysville',
#   974: 'ft myers beach',
#   975: 'richboro',
#   976: 'san mateo',
#   977: 'riedstadt',
#   978: 'dumas',
#   979: 'troy',
#   980: 'denton',
#   981: 'onalaska',
#   982: 'north avoca',
#   983: 'barstow',
#   984: 'upper township',
#   985: 'amherst',
#   986: 'springdale',
#   987: 'wirtz',
#   988: 'lakeland,',
#   989: 'venice',
#   990: 'ballston spa',
#   991: 'corrales',
#   992: 'perkasie',
#   993: 'west lawn',
#   994: 'falls church',
#   995: 'avalon',
#   996: 'la cienega',
#   997: 'north haven',
#   998: 'nunspeet',
#   999: 'roscoe',
#   ...},
#  'state': {0: 'california',
#   1: 'texas',
#   2: 'ontario',
#   3: 'florida',
#   4: 'new york',
#   5: 'illinois',
#   6: 'washington',
#   7: 'georgia',
#   8: 'pennsylvania',
#   9: 'virginia',
#   10: 'ohio',
#   11: 'missouri',
#   12: 'oregon',
#   13: 'michigan',
#   14: 'new jersey',
#   15: 'maryland',
#   16: 'north carolina',
#   17: 'british columbia',
#   18: 'massachusetts',
#   19: 'minnesota',
#   20: 'england',
#   21: 'alberta',
#   22: 'arizona',
#   23: 'wisconsin',
#   24: 'colorado',
#   25: 'tennessee',
#   26: 'south carolina',
#   27: 'connecticut',
#   28: 'kansas',
#   29: 'indiana',
#   30: 'alabama',
#   31: 'kentucky',
#   32: 'hawaii',
#   33: 'new mexico',
#   34: 'west virginia',
#   35: 'oklahoma',
#   36: 'iowa',
#   37: 'nebraska',
#   38: 'new hampshire',
#   39: 'nevada',
#   40: 'louisiana',
#   41: 'new south wales',
#   42: 'new brunswick',
#   43: 'utah',
#   44: 'arkansas',
#   45: 'maine',
#   46: 'nova scotia',
#   47: 'lisboa',
#   48: 'nordrhein-westfalen',
#   49: 'quebec',
#   50: 'alaska',
#   51: 'victoria',
#   52: 'hessen',
#   53: 'rhode island',
#   54: 'south dakota',
#   55: 'idaho',
#   56: 'canterbury',
#   57: 'vermont',
#   58: 'selangor',
#   59: 'manitoba',
#   60: 'baden-wuerttemberg',
#   61: 'bayern',
#   62: 'catalunya',
#   63: 'saskatchewan',
#   64: 'mississippi',
#   65: 'hamburg',
#   66: 'montana',
#   67: 'delaware',
#   68: 'north dakota',
#   69: 'barcelona',
#   70: 'madrid',
#   71: 'dc',
#   72: 'queensland',
#   73: 'scotland',
#   74: 'ap',
#   75: 'south australia',
#   76: 'ile de france',
#   77: 'wyoming',
#   78: 'western australia',
#   79: 'setúbal',
#   80: 'wales',
#   81: 'gelderland',
#   82: 'distrito nacional',
#   83: 'baden-württemberg',
#   84: 'sarawak',
#   85: 'tehran',
#   86: 'shanghai',
#   87: 'berlin',
#   88: 'newfoundland',
#   89: 'porto',
#   90: 'london',
#   91: 'overijssel',
#   92: 'niedersachsen',
#   93: 'wien',
#   94: 'rheinland-pfalz',
#   95: 'são paulo',
#   96: 'vizcaya',
#   97: 'federal territory',
#   98: 'oslo',
#   99: 'bretagne',
#   100: 'lisbon',
#   101: 'toscana',
#   102: 'australian capital territory',
#   103: 'vienna',
#   104: 'vlaams-brabant',
#   105: 'zuid-holland',
#   106: 'stockholm',
#   107: 'bavaria',
#   108: 'sachsen',
#   109: 'alsace',
#   110: 'uusimaa',
#   111: 'otago',
#   112: 'yukon territory',
#   113: 'lombardia',
#   114: 'vaud',
#   115: 'suffolk',
#   116: 'kuala lumpur',
#   117: 'prahova',
#   118: 'singapore',
#   119: 'ga.',
#   120: 'utrecht',
#   121: 'albay',
#   122: 'wilayah persekutuan',
#   123: 'rhône-alpes',
#   124: 'zürich',
#   125: 'pas de calais',
#   126: 'lazio',
#   127: 'pirkanmaa',
#   128: 'ae',
#   129: 'surrey',
#   130: 'acworth',
#   131: 'emilia romagna',
#   132: 'berkshire',
#   133: 'wiltshire',
#   134: 'oberoesterreich',
#   135: 'doha',
#   136: 'dublin',
#   137: 'barreiro',
#   138: 'noord holland',
#   139: 'bremen',
#   140: 'makati',
#   141: 'manila',
#   142: 'bern',
#   143: 'nord',
#   144: 'basel-stadt',
#   145: 'aragón',
#   146: 'kent',
#   147: 'zaragoza',
#   148: 'cantabria',
#   149: 'lancashire',
#   150: 'planet',
#   151: 'noord-holland',
#   152: 'tasmania',
#   153: 'ca',
#   154: 'asturias',
#   155: 'ile-de-france',
#   156: 'fribourg',
#   157: 'pontevedra',
#   158: 'haute-garonne',
#   159: 'cadiz',
#   160: 'derbyshire',
#   161: 'sachsen-anhalt',
#   162: 'pays de la loire',
#   163: 'valencia',
#   164: 'seine saint-denis',
#   165: 'álava',
#   166: 'thueringen',
#   167: 'prince edward island',
#   168: 'selangor darul ehsan',
#   169: 'paris',
#   170: 'huntingdon',
#   171: 'cáceres',
#   172: 'hampshire',
#   173: 'sevilla',
#   174: 'maraval',
#   175: 'tx',
#   176: 'schleswig-holstein',
#   177: 'kuwait',
#   178: 'keighley',
#   179: 'kyoto',
#   180: 'bizkaia',
#   181: 'dtto federal',
#   182: 'south yorkshire',
#   183: 'steiermark',
#   184: 'loures',
#   185: 'nm',
#   186: 'sabah',
#   187: 'wellington',
#   188: 'savoie',
#   189: 'zug',
#   190: 'limburg',
#   191: 'bulacan',
#   192: 'tokyo',
#   193: 'tirol',
#   194: 'québec',
#   195: 'zuid holland',
#   196: 'cheshire',
#   197: 'national capital region',
#   198: 'noord-brabant',
#   199: 'languedoc roussillon',
#   200: 'nottinghamshire',
#   201: 'braga',
#   202: 'west midlands',
#   203: 'auckland',
#   204: 'leinster',
#   205: 'co. dublin',
#   206: 'leicestershire',
#   207: 'north yorkshire',
#   208: 'ourense',
#   209: 'normandie',
#   210: 'zurich',
#   211: 'luzern',
#   212: 'fukuoka',
#   213: 'west yorkshire',
#   214: 'puerto rico',
#   215: 'euskadi',
#   216: 'ga',
#   217: 'trentino alto adige',
#   218: 'franche-comté',
#   219: 'geneva',
#   220: 'illes balears',
#   221: 'midi-pyrénées',
#   222: 'metro manila',
#   223: 'penang',
#   224: 'varsinais-suomi',
#   225: 'cambridgeshire',
#   226: 'reykjavik',
#   227: 'manawatu',
#   228: 'ncr',
#   229: 'aveiro',
#   230: 'lombardy',
#   231: 'conwy',
#   232: 'umbria',
#   233: 'jalisco',
#   234: 'isle of wight',
#   235: 'melaka',
#   236: 'uppland',
#   237: 'piemonte',
#   238: 'nj',
#   239: 'northern territory',
#   240: 'coimbra',
#   241: 'isle of man',
#   242: 'woj. mazowieckie',
#   243: 'iasi',
#   244: 'tyne & wear',
#   245: 'rio grande do sul',
#   246: 'bedfordshire',
#   247: 'kanton zürich',
#   248: 'mississippi39571',
#   249: 'northern ireland',
#   250: 'my own little world',
#   251: 'loire atlantique',
#   252: 'dolj',
#   253: 'aragon',
#   254: 'santa cruz de tenerife',
#   255: 'kildare',
#   256: 'va',
#   257: 'baleares',
#   258: 'bc',
#   259: 'michigan usa',
#   260: 'fl 33157',
#   261: 'hauts-de-seine',
#   262: 'east yorkshire',
#   263: 'wa',
#   264: 'perak',
#   265: 'buckinghamshire',
#   266: 'satakunta',
#   267: 'sjælland',
#   268: 'rhone-alpes',
#   269: 'worcestershire',
#   270: 'pernambuco',
#   271: 'norwich',
#   272: 'friuli venezia giulia',
#   273: 'västerbotten',
#   274: 'aargau',
#   275: 'champagne-ardenne',
#   276: 'subang jaya',
#   277: 'groningen',
#   278: 'west sussex',
#   279: 'armed forces pacific',
#   280: 'san josé',
#   281: 'cumbria',
#   282: 'andalucia',
#   283: 'zuerich',
#   284: 'la rioja',
#   285: 'veneto',
#   286: 'bavaria/bayern',
#   287: 'brandenburg',
#   288: 'buenos aires',
#   289: 'oxon',
#   290: 'vest-agder',
#   291: 'armed services europe',
#   292: 'málaga',
#   293: 'gunma',
#   294: 'distrito federal',
#   295: 'taiwan',
#   296: 'rhône alpes',
#   297: 'lothian',
#   298: 'keski-suomi',
#   299: 'rangoon',
#   300: 'rio de janeiro',
#   301: 'granollers',
#   302: '.',
#   303: 'patrick henry village',
#   304: 'kedah',
#   305: 'catalonia',
#   306: 'quinta región',
#   307: 'miraflores',
#   308: 'deux-sèvres',
#   309: 'ticino',
#   310: 'nrw',
#   311: 'dr.',
#   312: 'sicilia',
#   313: 'aomori-ken',
#   314: 'oh',
#   315: 'ks',
#   316: 'franche comte',
#   317: 'vienne',
#   318: 'yedor',
#   319: 'prague',
#   320: 'haineut',
#   321: 'castilla y león',
#   322: 'cataluña',
#   323: 'tn',
#   324: 'aquitaine',
#   325: 'ge',
#   326: 'marlborough',
#   327: 'vlaams brabant',
#   328: 'kowloon',
#   329: 'ma',
#   330: 'salzburg',
#   331: 'nunavut',
#   332: 'pohjois-pohjanmaa',
#   333: 'västergötland',
#   334: 'long island',
#   335: 'provence alpes côte d`azur',
#   336: 'maharashtra',
#   337: 'normandy',
#   338: 'picardie',
#   339: 'avon',
#   340: 'attiki',
#   341: 'central america',
#   342: 'kyiv',
#   343: 'il',
#   344: 'andhra pradesh',
#   345: 'campania',
#   346: 'taranaki',
#   347: '_',
#   348: 'western pennsylvania',
#   349: 'indre et loire',
#   350: 'norfolk',
#   351: 'etelä-suomen lääni',
#   352: 'niederoesterreich',
#   353: 'lleida',
#   354: 'merseyside',
#   355: 'oxfordshire',
#   356: 'michigan/new jersey',
#   357: 'athens',
#   358: 'bihor',
#   359: 'västra götalands län',
#   360: 'sinaloa',
#   361: 'rhone',
#   362: 'western cape',
#   363: 'famalicão',
#   364: 'poitou-charentes',
#   365: 'cascais',
#   366: 'baselland',
#   367: 'ny',
#   368: 'north holland',
#   369: 'virgin islands',
#   370: 'middlesex',
#   371: 'n carolina',
#   372: 'schaffhausen',
#   373: 'st. gallen',
#   374: 'sichuan',
#   375: 'solothurn',
#   376: 'tarragona',
#   377: 'medan hawalli',
#   378: 'hong kong',
#   379: 'grand bahama',
#   380: 'petach tikvah',
#   381: 'ile d`oleron',
#   382: 'jersey',
#   383: 'gipuzkoa',
#   384: 'st.gallen',
#   385: 'manchester',
#   386: 'gautang',
#   387: 'maramures',
#   388: 'skåne',
#   389: 'northwest territories',
#   390: 'islas canarias',
#   391: 'cairo',
#   392: '-',
#   393: 'sussex',
#   394: 'badajoz',
#   395: 'kelantan',
#   396: 'central',
#   397: 'laguna',
#   398: 'andalucía',
#   399: 'co',
#   400: 'antwerpen',
#   401: 'south gyeongsang',
#   402: 'vic',
#   403: 'alicante',
#   404: 'neuchâtel',
#   405: 'namur',
#   406: 'davao del sur',
#   407: 'takaka',
#   408: 'shiga',
#   409: 'france',
#   410: 'haute-saône',
#   411: 'navarra',
#   412: 'cebu',
#   413: 'uk',
#   414: 'provence',
#   415: 'yongsan-gu',
#   416: 'tokyo ku',
#   417: 'zeeland',
#   418: 'sao paulo',
#   419: 'brussels',
#   420: 'tokyo-to',
#   421: 'state of continuing flux',
#   422: 'somerset',
#   423: 'estremadura',
#   424: 'pest megye',
#   425: 's. carolina',
#   426: 'zh',
#   427: 'genève',
#   428: 'vigo pontevedra',
#   429: 'carabobo',
#   430: 'catalunya - barcelona',
#   431: 'n.p.',
#   432: 'estremadura,',
#   433: 'murcia',
#   434: 'sharon',
#   435: 'north island',
#   436: 'cornwall',
#   437: 'kl',
#   438: 'd.n.',
#   439: 'espinho',
#   440: 'etelä-savo',
#   441: 'preveza',
#   442: 'beijing',
#   443: ',',
#   444: 'ak.',
#   445: 's yorkshire',
#   446: 'cairo governate',
#   447: 'essex',
#   448: 'thüringen',
#   449: 'euskal herria',
#   450: 'val d`oise',
#   451: 'basel',
#   452: 'fukui',
#   453: 'florida keys',
#   454: 'saarland',
#   455: 'castilla y leon',
#   456: 'puglia',
#   457: 'rotterdam',
#   458: 'south island',
#   459: 'fife',
#   460: 'marche',
#   461: 'drenthe',
#   462: 'kyoung sang buk do',
#   463: 'bari',
#   464: 'maadi',
#   465: 'etela suomi',
#   466: 'teesside',
#   467: 'idf',
#   468: 'was in singas now in shangers',
#   469: 'bulgaria',
#   470: 'lincolnshire',
#   471: '<foreign>',
#   472: 'sarthe',
#   473: 'brabant',
#   474: 'jakarta',
#   475: 'bergamo',
#   476: 'spain',
#   477: 'china',
#   478: 'paca',
#   479: 'australia',
#   480: 'valcea',
#   481: 'naval air station keflavik',
#   482: 'hesse',
#   483: 'istanbul',
#   484: 'tuscany - chiantishire',
#   485: 'nord pas de calais',
#   486: 'oberösterreich',
#   487: 'staffordshire',
#   488: 'beira litoral',
#   489: 'sg',
#   490: 'york',
#   491: 'comunidad valenciana',
#   492: 'minas gerais',
#   493: 'alpes maritimes',
#   494: 'gloucestershire',
#   495: 'covilhã',
#   496: 'trás-os-montes',
#   497: 'oahu',
#   498: 'san jose',
#   499: 'unknown',
#   500: 'não há cá disso ^^',
#   501: 'vientiane',
#   502: 'bourgogne',
#   503: 'girona',
#   504: 'halland',
#   505: 'mi',
#   506: 'saitama',
#   507: 'bacau',
#   508: 'punjab',
#   509: 'estado de méxico',
#   510: 'yvelines',
#   511: 'delhi',
#   512: 'leiria',
#   513: 'united kingdom',
#   514: 'almada',
#   515: 'xxxxxx',
#   516: 'hawkes bay',
#   517: 'vaslui',
#   518: 'bristol',
#   519: 'west indies',
#   520: 'none',
#   521: 'anywhere - usa',
#   522: 'champagne ardennes',
#   523: 'lorraine',
#   524: 'south waikato',
#   525: 'apo',
#   526: 'south korea',
#   527: 'seixal',
#   528: 'cairo governorate',
#   529: 'alto alentejo',
#   530: 'glasgow',
#   531: 'act',
#   532: 'milano',
#   533: 'sintra',
#   534: 'b. c.',
#   535: 'haute-savoie',
#   536: 'franconia',
#   537: 'granada',
#   538: 'a coruña',
#   539: 'alava',
#   540: 'osaka',
#   541: 'w.p',
#   542: 'yucatan',
#   543: 'na/',
#   544: 'baden württemberg',
#   545: 'jaen-andalucia',
#   546: 'hasharon',
#   547: 'lima',
#   548: 'país valencià',
#   549: 'ahmedi',
#   550: 'luxembourg ville',
#   551: 'tullow',
#   552: 'ehime-ken',
#   553: 'mexico city',
#   554: 'calabria',
#   555: 'asturies',
#   556: 'paraná',
#   557: 'pohjanmaa',
#   558: 'nitriansky kraj',
#   559: 'noordoostpolder',
#   560: 'heredia',
#   561: 'ok',
#   562: 'las palmas',
#   563: 'herault',
#   564: 'minnasota',
#   565: 'or',
#   566: 'minho',
#   567: 'soria',
#   568: 'hyogo',
#   569: 'quit',
#   570: 'toamasina',
#   571: 'luxembourg',
#   572: 'galicia',
#   573: 'liguria',
#   574: 'bohemia',
#   575: 'país vasco',
#   576: 'liège',
#   577: 'sheffield',
#   578: 'okinawa',
#   579: 'antwerp',
#   580: 'sardegna',
#   581: 'wi',
#   582: 'europe',
#   583: 's. devon',
#   584: 'n/z',
#   585: 'karnataka',
#   586: 'basse normandie',
#   587: 'galati',
#   588: 'tayside',
#   589: 'lancaster',
#   590: 'tyne and wear',
#   591: 'co. louth',
#   592: 'i sometimes live in hong kong',
#   593: 'mecklenburg-vorpommern',
#   594: 'basque country (euskal herria)',
#   595: 'ribatejo',
#   596: 'toapayoh',
#   597: 'tobago',
#   598: 'muswell hill',
#   599: 'fyn',
#   600: 'city',
#   601: 'trondheim',
#   602: 'greater london',
#   603: 'kanagawa',
#   604: 'baja california sur',
#   605: 'haut de seine',
#   606: 'côte d`azur',
#   607: 'aomori prefecture',
#   608: 'ag',
#   609: 'córdoba',
#   610: 'nordrhein- westfalen',
#   611: 'haute normandie',
#   612: 'modena',
#   613: 'cork',
#   614: 'españa',
#   615: 'gauteng',
#   616: 'durham',
#   617: 'roma',
#   618: 'samos',
#   619: 'nord-pas-de-calais',
#   620: 'castilla',
#   621: 'st andrew`s',
#   622: 'guipúzcoa',
#   623: 'ag/bs',
#   624: 'sp',
#   625: 'hainault',
#   626: 'isere',
#   627: 'nairobi',
#   628: 'alajuela',
#   629: 'renfrewshire',
#   630: 'rhone alpes',
#   631: 'wiltshire,',
#   632: 'washington state',
#   633: 'alentejo',
#   634: 'venezia',
#   635: 'thurgau',
#   636: 'haifa',
#   637: 'sydney',
#   638: 'rodney district'},
#  'country': {0: 'usa',
#   1: 'canada',
#   2: 'united kingdom',
#   3: 'germany',
#   4: 'australia',
#   5: 'spain',
#   6: 'portugal',
#   7: 'france',
#   8: 'malaysia',
#   9: 'netherlands',
#   10: 'new zealand',
#   11: 'switzerland',
#   12: 'italy',
#   13: 'austria',
#   14: 'philippines',
#   15: 'brazil',
#   16: 'finland',
#   17: 'dominican republic',
#   18: 'china',
#   19: 'iran',
#   20: 'sweden',
#   21: 'norway',
#   22: 'belgium',
#   23: 'japan',
#   24: 'england, united kingdom',
#   25: 'romania',
#   26: 'ireland',
#   27: 'us',
#   28: 'singapore',
#   29: 'new york, georgia, usa',
#   30: 'qatar',
#   31: 'phillipines',
#   32: 'far away...',
#   33: 'mexico',
#   34: 'kuwait',
#   35: 'okinawa, japan',
#   36: 'cambridgeshire, united kingdom',
#   37: 'venezuela',
#   38: 'united state',
#   39: 'trinidad and tobago',
#   40: 'antarctica',
#   41: 'west yorkshire, united kingdom',
#   42: 'hong kong',
#   43: 'greece',
#   44: 'united states',
#   45: 'india',
#   46: 'iceland',
#   47: 'costa rica',
#   48: 'denmark',
#   49: 'egypt',
#   50: 'poland',
#   51: ',',
#   52: 'south africa',
#   53: 'canary islands, spain',
#   54: 'israel',
#   55: 'florida, usa',
#   56: 'south korea',
#   57: 'bahamas',
#   58: 'taiwan',
#   59: 'chile',
#   60: 'czech republic',
#   61: 'argentina',
#   62: 'burma',
#   63: 'new york, usa',
#   64: 'usa, kansas, usa',
#   65: 'luxembourg',
#   66: 'ukraine',
#   67: 'illinois, usa',
#   68: 'michigan, usa',
#   69: 'honduras',
#   70: 'saint lucia',
#   71: 'van wert',
#   72: 'idaho, usa',
#   73: 'euskal herria',
#   74: 'tennessee, usa',
#   75: 'england',
#   76: 'andalucia, spain',
#   77: 'british columbia, canada',
#   78: 'america',
#   79: 'hungary',
#   80: 'dc, usa',
#   81: 'seoul, south korea',
#   82: 'nz',
#   83: 'bahrain',
#   84: 'uruguay',
#   85: 'barbados',
#   86: 'laos',
#   87: 'españa',
#   88: 'italia',
#   89: 'virginia, usa',
#   90: 'pakistan',
#   91: 'singapore, singapore',
#   92: 'bulgaria',
#   93: 'catalonia',
#   94: 'u.k.',
#   95: 'wales',
#   96: 'turkey',
#   97: 'framingham',
#   98: 'rutherford',
#   99: 'hawaii, usa',
#   100: 'iceland, iceland',
#   101: 'peru',
#   102: 'slovakia',
#   103: 'quit',
#   104: 'co. carlow, ireland',
#   105: 'deutschland',
#   106: 'madagascar',
#   107: 'guernsey, channel islands',
#   108: 'scotland',
#   109: 'ysa',
#   110: 'tanzania',
#   111: 'kenya',
#   112: 'west indies, tobago',
#   113: 'ohio, usa',
#   114: 'united kindgonm',
#   115: 'alderney',
#   116: 'u.s.a.',
#   117: 'new south wales, australia',
#   118: 'oregon, usa'}}

# %% [markdown]
# ### Build data batches

# %%
train_data = RecBatch(
    data = train_df,
    cols_sparse = [c+'_enc' for c in cols_sparse],
    cols_dense = cols_dense,
    col_label = "label",
    batch_size = 100,
    num_generated_batches = 20,
    seed = 123,
    device = device
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 train_data = RecBatch(
#       2     data = train_df,
#       3     cols_sparse = [c+'_enc' for c in cols_sparse],
#       4     cols_dense = cols_dense,
#       5     col_label = "label",
#       6     batch_size = 100,
#       7     num_generated_batches = 20,
#       8     seed = 123,
#       9     device = device
#      10 )
#
# NameError: name 'RecBatch' is not defined
